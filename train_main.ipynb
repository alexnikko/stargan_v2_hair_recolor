# %%
#!g1.1

import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from glob import glob
import os
import numpy as np
import random
from pathlib import Path
from itertools import chain

from munch import Munch

import torch
from torch.utils import data
from torch.utils.data.sampler import WeightedRandomSampler
from torchvision import transforms
from torchvision.datasets import ImageFolder

from collections import namedtuple
from copy import deepcopy
from functools import partial

import cv2
from skimage.filters import gaussian
import torch.nn as nn
import torch.nn.functional as F
import copy
import math

from os.path import join as ospj
import json
import glob
from shutil import copyfile

from tqdm import tqdm
import ffmpeg

import torchvision
import torchvision.utils as vutils
import time
import datetime

# %%
#!g1.1
# root = '/home/jupyter/mnt/datasets/k_hairstyle_full/'
# annot = pd.read_pickle('/home/jupyter/mnt/datasets/k_hairstyle/annotation.pkl')
# df = annot[(annot.color != 'two-tone') & (annot.color != 'others')]
# df = df.sample(frac=1)
df = pd.read_pickle('df_final.pkl')
df = df.sample(frac=1)

files = np.array(df.path.tolist())
labels = np.array(df.label.tolist())

print(len(files), len(labels))
print(labels.min(), labels.max())

# paths = df.path.tolist()
# colors = df.color.tolist()

# unique_colors = set(colors)

# color2idx = {
#     color: idx
#     for idx, color in enumerate(unique_colors)
# }

# idx2color = {
#     idx: color
#     for color, idx in color2idx.items()
# }

# labels = np.array([color2idx[color] for color in colors])
# files = np.array([os.path.join(root, path) for path in paths])
# Out:
# 15000 15000
# 0 2

# %%
#!g1.1
def listdir(dname):
    fnames = list(chain(*[list(Path(dname).rglob('*.' + ext))
                          for ext in ['png', 'jpg', 'jpeg', 'JPG']]))
    return fnames


class DefaultDataset(data.Dataset):
    def __init__(self, files, transform=None):
        self.samples = files#listdir(root)
#         self.samples.sort()
        self.transform = transform
        self.targets = None

    def __getitem__(self, index):
        fname = self.samples[index]
        img = Image.open(fname).convert('RGB')
        if self.transform is not None:
            img = self.transform(img)
        return img

    def __len__(self):
        return len(self.samples)


class DefaultLabeledDataset(data.Dataset):
    def __init__(self, files, labels, transform=None):
        self.samples = files #listdir(root)
        self.transform = transform
        self.targets = labels

    def __getitem__(self, index):
        fname = self.samples[index]
        target = self.targets[index]
        img = Image.open(fname).convert('RGB')
        if self.transform is not None:
            img = self.transform(img)
        return img, target

    def __len__(self):
        return len(self.samples)


class ReferenceDataset(data.Dataset):
    def __init__(self, files, labels, transform=None):
        self.samples, self.targets = self._make_dataset(files, labels)
        self.transform = transform

    def _make_dataset(self, files, labels):
        num_domains = labels.max() + 1
        print(f'NUM DOMAINS = {num_domains}')
        fnames, fnames2, targets = [], [], []
        for label in range(num_domains):
            mask = labels == label
            label_files = files[mask]
            fnames += random.sample(label_files.tolist(), sum(mask))
            fnames2 += random.sample(fnames, sum(mask))
            targets += [label] * sum(mask)
        return list(zip(fnames, fnames2)), labels

    def __getitem__(self, index):
        fname, fname2 = self.samples[index]
        label = self.targets[index]
        img = Image.open(fname).convert('RGB')
        img2 = Image.open(fname2).convert('RGB')
        if self.transform is not None:
            img = self.transform(img)
            img2 = self.transform(img2)
        return img, img2, label

    def __len__(self):
        return len(self.targets)


def _make_balanced_sampler(labels):
    class_counts = np.bincount(labels)
    class_weights = 1. / class_counts
    weights = class_weights[labels]
    return WeightedRandomSampler(weights, len(weights))


def get_train_loader(files, labels, which='source', img_size=256,
                     batch_size=8, prob=0.5, num_workers=4):
    print('Preparing DataLoader to fetch %s images '
          'during the training phase...' % which)

    crop = transforms.RandomResizedCrop(
        img_size, scale=[0.8, 1.0], ratio=[0.9, 1.1])
    rand_crop = transforms.Lambda(
        lambda x: crop(x) if random.random() < prob else x)

    transform = transforms.Compose([
        rand_crop,
        transforms.Resize([img_size, img_size]),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5],
                             std=[0.5, 0.5, 0.5]),
    ])

    if which == 'source':
        dataset = DefaultLabeledDataset(files, labels, transform)
    elif which == 'reference':
        dataset = ReferenceDataset(files, labels, transform)
    else:
        raise NotImplementedError

    sampler = _make_balanced_sampler(dataset.targets)
    return data.DataLoader(dataset=dataset,
                           batch_size=batch_size,
                           sampler=sampler,
                           num_workers=num_workers,
                           pin_memory=True,
                           drop_last=True)


def get_eval_loader(files, img_size=256, batch_size=32,
                    imagenet_normalize=True, shuffle=True,
                    num_workers=4, drop_last=False):
    print('Preparing DataLoader for the evaluation phase...')
    if imagenet_normalize:
        height, width = 299, 299
        mean = [0.485, 0.456, 0.406]
        std = [0.229, 0.224, 0.225]
    else:
        height, width = img_size, img_size
        mean = [0.5, 0.5, 0.5]
        std = [0.5, 0.5, 0.5]

    transform = transforms.Compose([
        transforms.Resize([img_size, img_size]),
        transforms.Resize([height, width]),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean, std=std)
    ])

    dataset = DefaultDataset(files, transform=transform)
    return data.DataLoader(dataset=dataset,
                           batch_size=batch_size,
                           shuffle=shuffle,
                           num_workers=num_workers,
                           pin_memory=True,
                           drop_last=drop_last)


def get_test_loader(files, labels, img_size=256, batch_size=32,
                    shuffle=True, num_workers=4):
    print('Preparing DataLoader for the generation phase...')
    transform = transforms.Compose([
        transforms.Resize([img_size, img_size]),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5],
                             std=[0.5, 0.5, 0.5]),
    ])

    dataset = DefaultLabeledDataset(files, labels, transform)
    return data.DataLoader(dataset=dataset,
                           batch_size=batch_size,
                           shuffle=shuffle,
                           num_workers=num_workers,
                           pin_memory=True)


class InputFetcher:
    def __init__(self, loader, loader_ref=None, latent_dim=16, mode=''):
        self.loader = loader
        self.loader_ref = loader_ref
        self.latent_dim = latent_dim
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.mode = mode

    def _fetch_inputs(self):
        try:
            x, y = next(self.iter)
        except (AttributeError, StopIteration):
            self.iter = iter(self.loader)
            x, y = next(self.iter)
        return x, y

    def _fetch_refs(self):
        try:
            x, x2, y = next(self.iter_ref)
        except (AttributeError, StopIteration):
            self.iter_ref = iter(self.loader_ref)
            x, x2, y = next(self.iter_ref)
        return x, x2, y

    def __next__(self):
        x, y = self._fetch_inputs()
        if self.mode == 'train':
            x_ref, x_ref2, y_ref = self._fetch_refs()
            z_trg = torch.randn(x.size(0), self.latent_dim)
            z_trg2 = torch.randn(x.size(0), self.latent_dim)
            inputs = Munch(x_src=x, y_src=y, y_ref=y_ref,
                           x_ref=x_ref, x_ref2=x_ref2,
                           z_trg=z_trg, z_trg2=z_trg2)
        elif self.mode == 'val':
            x_ref, y_ref = self._fetch_inputs()
            inputs = Munch(x_src=x, y_src=y,
                           x_ref=x_ref, y_ref=y_ref)
        elif self.mode == 'test':
            inputs = Munch(x=x, y=y)
        else:
            raise NotImplementedError

        return Munch({k: v.to(self.device)
                      for k, v in inputs.items()})

# %%
#!g1.1
## THIS IS CORE WING
def get_preds_fromhm(hm):
    max, idx = torch.max(
        hm.view(hm.size(0), hm.size(1), hm.size(2) * hm.size(3)), 2)
    idx += 1
    preds = idx.view(idx.size(0), idx.size(1), 1).repeat(1, 1, 2).float()
    preds[..., 0].apply_(lambda x: (x - 1) % hm.size(3) + 1)
    preds[..., 1].add_(-1).div_(hm.size(2)).floor_().add_(1)

    for i in range(preds.size(0)):
        for j in range(preds.size(1)):
            hm_ = hm[i, j, :]
            pX, pY = int(preds[i, j, 0]) - 1, int(preds[i, j, 1]) - 1
            if pX > 0 and pX < 63 and pY > 0 and pY < 63:
                diff = torch.FloatTensor(
                    [hm_[pY, pX + 1] - hm_[pY, pX - 1],
                     hm_[pY + 1, pX] - hm_[pY - 1, pX]])
                preds[i, j].add_(diff.sign_().mul_(.25))

    preds.add_(-0.5)
    return preds


class HourGlass(nn.Module):
    def __init__(self, num_modules, depth, num_features, first_one=False):
        super(HourGlass, self).__init__()
        self.num_modules = num_modules
        self.depth = depth
        self.features = num_features
        self.coordconv = CoordConvTh(64, 64, True, True, 256, first_one,
                                     out_channels=256,
                                     kernel_size=1, stride=1, padding=0)
        self._generate_network(self.depth)

    def _generate_network(self, level):
        self.add_module('b1_' + str(level), ConvBlock(256, 256))
        self.add_module('b2_' + str(level), ConvBlock(256, 256))
        if level > 1:
            self._generate_network(level - 1)
        else:
            self.add_module('b2_plus_' + str(level), ConvBlock(256, 256))
        self.add_module('b3_' + str(level), ConvBlock(256, 256))

    def _forward(self, level, inp):
        up1 = inp
        up1 = self._modules['b1_' + str(level)](up1)
        low1 = F.avg_pool2d(inp, 2, stride=2)
        low1 = self._modules['b2_' + str(level)](low1)

        if level > 1:
            low2 = self._forward(level - 1, low1)
        else:
            low2 = low1
            low2 = self._modules['b2_plus_' + str(level)](low2)
        low3 = low2
        low3 = self._modules['b3_' + str(level)](low3)
        up2 = F.interpolate(low3, scale_factor=2, mode='nearest')

        return up1 + up2

    def forward(self, x, heatmap):
        x, last_channel = self.coordconv(x, heatmap)
        return self._forward(self.depth, x), last_channel


class AddCoordsTh(nn.Module):
    def __init__(self, height=64, width=64, with_r=False, with_boundary=False):
        super(AddCoordsTh, self).__init__()
        self.with_r = with_r
        self.with_boundary = with_boundary
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        with torch.no_grad():
            x_coords = torch.arange(height).unsqueeze(1).expand(height, width).float()
            y_coords = torch.arange(width).unsqueeze(0).expand(height, width).float()
            x_coords = (x_coords / (height - 1)) * 2 - 1
            y_coords = (y_coords / (width - 1)) * 2 - 1
            coords = torch.stack([x_coords, y_coords], dim=0)  # (2, height, width)

            if self.with_r:
                rr = torch.sqrt(torch.pow(x_coords, 2) + torch.pow(y_coords, 2))  # (height, width)
                rr = (rr / torch.max(rr)).unsqueeze(0)
                coords = torch.cat([coords, rr], dim=0)

            self.coords = coords.unsqueeze(0).to(device)  # (1, 2 or 3, height, width)
            self.x_coords = x_coords.to(device)
            self.y_coords = y_coords.to(device)

    def forward(self, x, heatmap=None):
        """
        x: (batch, c, x_dim, y_dim)
        """
        coords = self.coords.repeat(x.size(0), 1, 1, 1)

        if self.with_boundary and heatmap is not None:
            boundary_channel = torch.clamp(heatmap[:, -1:, :, :], 0.0, 1.0)
            zero_tensor = torch.zeros_like(self.x_coords)
            xx_boundary_channel = torch.where(boundary_channel > 0.05, self.x_coords, zero_tensor).to(zero_tensor.device)
            yy_boundary_channel = torch.where(boundary_channel > 0.05, self.y_coords, zero_tensor).to(zero_tensor.device)
            coords = torch.cat([coords, xx_boundary_channel, yy_boundary_channel], dim=1)

        x_and_coords = torch.cat([x, coords], dim=1)
        return x_and_coords


class CoordConvTh(nn.Module):
    """CoordConv layer as in the paper."""
    def __init__(self, height, width, with_r, with_boundary,
                 in_channels, first_one=False, *args, **kwargs):
        super(CoordConvTh, self).__init__()
        self.addcoords = AddCoordsTh(height, width, with_r, with_boundary)
        in_channels += 2
        if with_r:
            in_channels += 1
        if with_boundary and not first_one:
            in_channels += 2
        self.conv = nn.Conv2d(in_channels=in_channels, *args, **kwargs)

    def forward(self, input_tensor, heatmap=None):
        ret = self.addcoords(input_tensor, heatmap)
        last_channel = ret[:, -2:, :, :]
        ret = self.conv(ret)
        return ret, last_channel


class ConvBlock(nn.Module):
    def __init__(self, in_planes, out_planes):
        super(ConvBlock, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_planes)
        conv3x3 = partial(nn.Conv2d, kernel_size=3, stride=1, padding=1, bias=False, dilation=1)
        self.conv1 = conv3x3(in_planes, int(out_planes / 2))
        self.bn2 = nn.BatchNorm2d(int(out_planes / 2))
        self.conv2 = conv3x3(int(out_planes / 2), int(out_planes / 4))
        self.bn3 = nn.BatchNorm2d(int(out_planes / 4))
        self.conv3 = conv3x3(int(out_planes / 4), int(out_planes / 4))

        self.downsample = None
        if in_planes != out_planes:
            self.downsample = nn.Sequential(nn.BatchNorm2d(in_planes),
                                            nn.ReLU(True),
                                            nn.Conv2d(in_planes, out_planes, 1, 1, bias=False))

    def forward(self, x):
        residual = x

        out1 = self.bn1(x)
        out1 = F.relu(out1, True)
        out1 = self.conv1(out1)

        out2 = self.bn2(out1)
        out2 = F.relu(out2, True)
        out2 = self.conv2(out2)

        out3 = self.bn3(out2)
        out3 = F.relu(out3, True)
        out3 = self.conv3(out3)

        out3 = torch.cat((out1, out2, out3), 1)
        if self.downsample is not None:
            residual = self.downsample(residual)
        out3 += residual
        return out3


class FAN(nn.Module):
    def __init__(self, num_modules=1, end_relu=False, num_landmarks=98, fname_pretrained=None):
        super(FAN, self).__init__()
        self.num_modules = num_modules
        self.end_relu = end_relu

        # Base part
        self.conv1 = CoordConvTh(256, 256, True, False,
                                 in_channels=3, out_channels=64,
                                 kernel_size=7, stride=2, padding=3)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = ConvBlock(64, 128)
        self.conv3 = ConvBlock(128, 128)
        self.conv4 = ConvBlock(128, 256)

        # Stacking part
        self.add_module('m0', HourGlass(1, 4, 256, first_one=True))
        self.add_module('top_m_0', ConvBlock(256, 256))
        self.add_module('conv_last0', nn.Conv2d(256, 256, 1, 1, 0))
        self.add_module('bn_end0', nn.BatchNorm2d(256))
        self.add_module('l0', nn.Conv2d(256, num_landmarks+1, 1, 1, 0))

        if fname_pretrained is not None:
            self.load_pretrained_weights(fname_pretrained)

    def load_pretrained_weights(self, fname):
        if torch.cuda.is_available():
            checkpoint = torch.load(fname)
        else:
            checkpoint = torch.load(fname, map_location=torch.device('cpu'))
        model_weights = self.state_dict()
        model_weights.update({k: v for k, v in checkpoint['state_dict'].items()
                              if k in model_weights})
        self.load_state_dict(model_weights)

    def forward(self, x):
        x, _ = self.conv1(x)
        x = F.relu(self.bn1(x), True)
        x = F.avg_pool2d(self.conv2(x), 2, stride=2)
        x = self.conv3(x)
        x = self.conv4(x)

        outputs = []
        boundary_channels = []
        tmp_out = None
        ll, boundary_channel = self._modules['m0'](x, tmp_out)
        ll = self._modules['top_m_0'](ll)
        ll = F.relu(self._modules['bn_end0']
                    (self._modules['conv_last0'](ll)), True)

        # Predict heatmaps
        tmp_out = self._modules['l0'](ll)
        if self.end_relu:
            tmp_out = F.relu(tmp_out)  # HACK: Added relu
        outputs.append(tmp_out)
        boundary_channels.append(boundary_channel)
        return outputs, boundary_channels

    @torch.no_grad()
    def get_heatmap(self, x, b_preprocess=True):
        ''' outputs 0-1 normalized heatmap '''
        x = F.interpolate(x, size=256, mode='bilinear')
        x_01 = x*0.5 + 0.5
        outputs, _ = self(x_01)
        heatmaps = outputs[-1][:, :-1, :, :]
        scale_factor = x.size(2) // heatmaps.size(2)
        if b_preprocess:
            heatmaps = F.interpolate(heatmaps, scale_factor=scale_factor,
                                     mode='bilinear', align_corners=True)
            heatmaps = preprocess(heatmaps)
        return heatmaps

    @torch.no_grad()
    def get_landmark(self, x):
        ''' outputs landmarks of x.shape '''
        heatmaps = self.get_heatmap(x, b_preprocess=False)
        landmarks = []
        for i in range(x.size(0)):
            pred_landmarks = get_preds_fromhm(heatmaps[i].cpu().unsqueeze(0))
            landmarks.append(pred_landmarks)
        scale_factor = x.size(2) // heatmaps.size(2)
        landmarks = torch.cat(landmarks) * scale_factor
        return landmarks


# ========================== #
#   Align related functions  #
# ========================== #


def tensor2numpy255(tensor):
    """Converts torch tensor to numpy array."""
    return ((tensor.permute(1, 2, 0).cpu().numpy() * 0.5 + 0.5) * 255).astype('uint8')


def np2tensor(image):
    """Converts numpy array to torch tensor."""
    return torch.FloatTensor(image).permute(2, 0, 1) / 255 * 2 - 1


class FaceAligner():
    def __init__(self, fname_wing, fname_celeba_mean, output_size):
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.fan = FAN(fname_pretrained=fname_wing).to(self.device).eval()
        scale = output_size // 256
        self.CELEB_REF = np.float32(np.load(fname_celeba_mean)['mean']) * scale
        self.xaxis_ref = landmarks2xaxis(self.CELEB_REF)
        self.output_size = output_size

    def align(self, imgs, output_size=256):
        ''' imgs = torch.CUDATensor of BCHW '''
        imgs = imgs.to(self.device)
        landmarkss = self.fan.get_landmark(imgs).cpu().numpy()
        for i, (img, landmarks) in enumerate(zip(imgs, landmarkss)):
            img_np = tensor2numpy255(img)
            img_np, landmarks = pad_mirror(img_np, landmarks)
            transform = self.landmarks2mat(landmarks)
            rows, cols, _ = img_np.shape
            rows = max(rows, self.output_size)
            cols = max(cols, self.output_size)
            aligned = cv2.warpPerspective(img_np, transform, (cols, rows), flags=cv2.INTER_LANCZOS4)
            imgs[i] = np2tensor(aligned[:self.output_size, :self.output_size, :])
        return imgs

    def landmarks2mat(self, landmarks):
        T_origin = points2T(landmarks, 'from')
        xaxis_src = landmarks2xaxis(landmarks)
        R = vecs2R(xaxis_src, self.xaxis_ref)
        S = landmarks2S(landmarks, self.CELEB_REF)
        T_ref = points2T(self.CELEB_REF, 'to')
        matrix = np.dot(T_ref, np.dot(S, np.dot(R, T_origin)))
        return matrix


def points2T(point, direction):
    point_mean = point.mean(axis=0)
    T = np.eye(3)
    coef = -1 if direction == 'from' else 1
    T[:2, 2] = coef * point_mean
    return T


def landmarks2eyes(landmarks):
    idx_left = np.array(list(range(60, 67+1)) + [96])
    idx_right = np.array(list(range(68, 75+1)) + [97])
    left = landmarks[idx_left]
    right = landmarks[idx_right]
    return left.mean(axis=0), right.mean(axis=0)


def landmarks2mouthends(landmarks):
    left = landmarks[76]
    right = landmarks[82]
    return left, right


def rotate90(vec):
    x, y = vec
    return np.array([y, -x])


def landmarks2xaxis(landmarks):
    eye_left, eye_right = landmarks2eyes(landmarks)
    mouth_left, mouth_right = landmarks2mouthends(landmarks)
    xp = eye_right - eye_left  # x' in pggan
    eye_center = (eye_left + eye_right) * 0.5
    mouth_center = (mouth_left + mouth_right) * 0.5
    yp = eye_center - mouth_center
    xaxis = xp - rotate90(yp)
    return xaxis / np.linalg.norm(xaxis)


def vecs2R(vec_x, vec_y):
    vec_x = vec_x / np.linalg.norm(vec_x)
    vec_y = vec_y / np.linalg.norm(vec_y)
    c = np.dot(vec_x, vec_y)
    s = np.sqrt(1 - c * c) * np.sign(np.cross(vec_x, vec_y))
    R = np.array(((c, -s, 0), (s, c, 0), (0, 0, 1)))
    return R


def landmarks2S(x, y):
    x_mean = x.mean(axis=0).squeeze()
    y_mean = y.mean(axis=0).squeeze()
    # vectors = mean -> each point
    x_vectors = x - x_mean
    y_vectors = y - y_mean

    x_norms = np.linalg.norm(x_vectors, axis=1)
    y_norms = np.linalg.norm(y_vectors, axis=1)

    indices = [96, 97, 76, 82]  # indices for eyes, lips
    scale = (y_norms / x_norms)[indices].mean()

    S = np.eye(3)
    S[0, 0] = S[1, 1] = scale
    return S


def pad_mirror(img, landmarks):
    H, W, _ = img.shape
    img = np.pad(img, ((H//2, H//2), (W//2, W//2), (0, 0)), 'reflect')
    small_blurred = gaussian(cv2.resize(img, (W, H)), H//100, multichannel=True)
    blurred = cv2.resize(small_blurred, (W * 2, H * 2)) * 255

    H, W, _ = img.shape
    coords = np.meshgrid(np.arange(H), np.arange(W), indexing="ij")
    weight_y = np.clip(coords[0] / (H//4), 0, 1)
    weight_x = np.clip(coords[1] / (H//4), 0, 1)
    weight_y = np.minimum(weight_y, np.flip(weight_y, axis=0))
    weight_x = np.minimum(weight_x, np.flip(weight_x, axis=1))
    weight = np.expand_dims(np.minimum(weight_y, weight_x), 2)**4
    img = img * weight + blurred * (1 - weight)
    landmarks += np.array([W//4, H//4])
    return img, landmarks


def align_faces(args, input_dir, output_dir):
    import os
    from torchvision import transforms
    from PIL import Image
    from core.utils import save_image

    aligner = FaceAligner(args.wing_path, args.lm_path, args.img_size)
    transform = transforms.Compose([
        transforms.Resize((args.img_size, args.img_size)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5],
                             std=[0.5, 0.5, 0.5]),
    ])

    fnames = os.listdir(input_dir)
    os.makedirs(output_dir, exist_ok=True)
    fnames.sort()
    for fname in fnames:
        image = Image.open(os.path.join(input_dir, fname)).convert('RGB')
        x = transform(image).unsqueeze(0)
        x_aligned = aligner.align(x)
        save_image(x_aligned, 1, filename=os.path.join(output_dir, fname))
        print('Saved the aligned image to %s...' % fname)


# ========================== #
#   Mask related functions   #
# ========================== #


def normalize(x, eps=1e-6):
    """Apply min-max normalization."""
    x = x.contiguous()
    N, C, H, W = x.size()
    x_ = x.view(N*C, -1)
    max_val = torch.max(x_, dim=1, keepdim=True)[0]
    min_val = torch.min(x_, dim=1, keepdim=True)[0]
    x_ = (x_ - min_val) / (max_val - min_val + eps)
    out = x_.view(N, C, H, W)
    return out


def truncate(x, thres=0.1):
    """Remove small values in heatmaps."""
    return torch.where(x < thres, torch.zeros_like(x), x)


def resize(x, p=2):
    """Resize heatmaps."""
    return x**p


def shift(x, N):
    """Shift N pixels up or down."""
    up = N >= 0
    N = abs(N)
    _, _, H, W = x.size()
    head = torch.arange(N)
    tail = torch.arange(H-N)

    if up:
        head = torch.arange(H-N)+N
        tail = torch.arange(N)
    else:
        head = torch.arange(N) + (H-N)
        tail = torch.arange(H-N)

    # permutation indices
    perm = torch.cat([head, tail]).to(x.device)
    out = x[:, :, perm, :]
    return out


IDXPAIR = namedtuple('IDXPAIR', 'start end')
index_map = Munch(chin=IDXPAIR(0 + 8, 33 - 8),
                  eyebrows=IDXPAIR(33, 51),
                  eyebrowsedges=IDXPAIR(33, 46),
                  nose=IDXPAIR(51, 55),
                  nostrils=IDXPAIR(55, 60),
                  eyes=IDXPAIR(60, 76),
                  lipedges=IDXPAIR(76, 82),
                  lipupper=IDXPAIR(77, 82),
                  liplower=IDXPAIR(83, 88),
                  lipinner=IDXPAIR(88, 96))
OPPAIR = namedtuple('OPPAIR', 'shift resize')


def preprocess(x):
    """Preprocess 98-dimensional heatmaps."""
    N, C, H, W = x.size()
    x = truncate(x)
    x = normalize(x)

    sw = H // 256
    operations = Munch(chin=OPPAIR(0, 3),
                       eyebrows=OPPAIR(-7*sw, 2),
                       nostrils=OPPAIR(8*sw, 4),
                       lipupper=OPPAIR(-8*sw, 4),
                       liplower=OPPAIR(8*sw, 4),
                       lipinner=OPPAIR(-2*sw, 3))

    for part, ops in operations.items():
        start, end = index_map[part]
        x[:, start:end] = resize(shift(x[:, start:end], ops.shift), ops.resize)

    zero_out = torch.cat([torch.arange(0, index_map.chin.start),
                          torch.arange(index_map.chin.end, 33),
                          torch.LongTensor([index_map.eyebrowsedges.start,
                                            index_map.eyebrowsedges.end,
                                            index_map.lipedges.start,
                                            index_map.lipedges.end])])
    x[:, zero_out] = 0

    start, end = index_map.nose
    x[:, start+1:end] = shift(x[:, start+1:end], 4*sw)
    x[:, start:end] = resize(x[:, start:end], 1)

    start, end = index_map.eyes
    x[:, start:end] = resize(x[:, start:end], 1)
    x[:, start:end] = resize(shift(x[:, start:end], -8), 3) + \
        shift(x[:, start:end], -24)

    # Second-level mask
    x2 = deepcopy(x)
    x2[:, index_map.chin.start:index_map.chin.end] = 0  # start:end was 0:33
    x2[:, index_map.lipedges.start:index_map.lipinner.end] = 0  # start:end was 76:96
    x2[:, index_map.eyebrows.start:index_map.eyebrows.end] = 0  # start:end was 33:51

    x = torch.sum(x, dim=1, keepdim=True)  # (N, 1, H, W)
    x2 = torch.sum(x2, dim=1, keepdim=True)  # mask without faceline and mouth

    x[x != x] = 0  # set nan to zero
    x2[x != x] = 0  # set nan to zero
    return x.clamp_(0, 1), x2.clamp_(0, 1)

# %%
#!g1.1
# THIS IS CORE MODEL
class ResBlk(nn.Module):
    def __init__(self, dim_in, dim_out, actv=nn.LeakyReLU(0.2),
                 normalize=False, downsample=False):
        super().__init__()
        self.actv = actv
        self.normalize = normalize
        self.downsample = downsample
        self.learned_sc = dim_in != dim_out
        self._build_weights(dim_in, dim_out)

    def _build_weights(self, dim_in, dim_out):
        self.conv1 = nn.Conv2d(dim_in, dim_in, 3, 1, 1)
        self.conv2 = nn.Conv2d(dim_in, dim_out, 3, 1, 1)
        if self.normalize:
            self.norm1 = nn.InstanceNorm2d(dim_in, affine=True)
            self.norm2 = nn.InstanceNorm2d(dim_in, affine=True)
        if self.learned_sc:
            self.conv1x1 = nn.Conv2d(dim_in, dim_out, 1, 1, 0, bias=False)

    def _shortcut(self, x):
        if self.learned_sc:
            x = self.conv1x1(x)
        if self.downsample:
            x = F.avg_pool2d(x, 2)
        return x

    def _residual(self, x):
        if self.normalize:
            x = self.norm1(x)
        x = self.actv(x)
        x = self.conv1(x)
        if self.downsample:
            x = F.avg_pool2d(x, 2)
        if self.normalize:
            x = self.norm2(x)
        x = self.actv(x)
        x = self.conv2(x)
        return x

    def forward(self, x):
        x = self._shortcut(x) + self._residual(x)
        return x / math.sqrt(2)  # unit variance


class AdaIN(nn.Module):
    def __init__(self, style_dim, num_features):
        super().__init__()
        self.norm = nn.InstanceNorm2d(num_features, affine=False)
        self.fc = nn.Linear(style_dim, num_features*2)

    def forward(self, x, s):
        h = self.fc(s)
        h = h.view(h.size(0), h.size(1), 1, 1)
        gamma, beta = torch.chunk(h, chunks=2, dim=1)
        return (1 + gamma) * self.norm(x) + beta


class AdainResBlk(nn.Module):
    def __init__(self, dim_in, dim_out, style_dim=64, w_hpf=0,
                 actv=nn.LeakyReLU(0.2), upsample=False):
        super().__init__()
        self.w_hpf = w_hpf
        self.actv = actv
        self.upsample = upsample
        self.learned_sc = dim_in != dim_out
        self._build_weights(dim_in, dim_out, style_dim)

    def _build_weights(self, dim_in, dim_out, style_dim=64):
        self.conv1 = nn.Conv2d(dim_in, dim_out, 3, 1, 1)
        self.conv2 = nn.Conv2d(dim_out, dim_out, 3, 1, 1)
        self.norm1 = AdaIN(style_dim, dim_in)
        self.norm2 = AdaIN(style_dim, dim_out)
        if self.learned_sc:
            self.conv1x1 = nn.Conv2d(dim_in, dim_out, 1, 1, 0, bias=False)

    def _shortcut(self, x):
        if self.upsample:
            x = F.interpolate(x, scale_factor=2, mode='nearest')
        if self.learned_sc:
            x = self.conv1x1(x)
        return x

    def _residual(self, x, s):
        x = self.norm1(x, s)
        x = self.actv(x)
        if self.upsample:
            x = F.interpolate(x, scale_factor=2, mode='nearest')
        x = self.conv1(x)
        x = self.norm2(x, s)
        x = self.actv(x)
        x = self.conv2(x)
        return x

    def forward(self, x, s):
        out = self._residual(x, s)
        if self.w_hpf == 0:
            out = (out + self._shortcut(x)) / math.sqrt(2)
        return out


class HighPass(nn.Module):
    def __init__(self, w_hpf, device):
        super(HighPass, self).__init__()
        self.register_buffer('filter',
                             torch.tensor([[-1, -1, -1],
                                           [-1, 8., -1],
                                           [-1, -1, -1]]) / w_hpf)

    def forward(self, x):
        filter = self.filter.unsqueeze(0).unsqueeze(1).repeat(x.size(1), 1, 1, 1)
        return F.conv2d(x, filter, padding=1, groups=x.size(1))


class Generator(nn.Module):
    def __init__(self, img_size=256, style_dim=64, max_conv_dim=512, w_hpf=1):
        super().__init__()
        dim_in = 2**14 // img_size
        self.img_size = img_size
        self.from_rgb = nn.Conv2d(3, dim_in, 3, 1, 1)
        self.encode = nn.ModuleList()
        self.decode = nn.ModuleList()
        self.to_rgb = nn.Sequential(
            nn.InstanceNorm2d(dim_in, affine=True),
            nn.LeakyReLU(0.2),
            nn.Conv2d(dim_in, 3, 1, 1, 0))

        # down/up-sampling blocks
        repeat_num = int(np.log2(img_size)) - 4
        if w_hpf > 0:
            repeat_num += 1
        for _ in range(repeat_num):
            dim_out = min(dim_in*2, max_conv_dim)
            self.encode.append(
                ResBlk(dim_in, dim_out, normalize=True, downsample=True))
            self.decode.insert(
                0, AdainResBlk(dim_out, dim_in, style_dim,
                               w_hpf=w_hpf, upsample=True))  # stack-like
            dim_in = dim_out

        # bottleneck blocks
        for _ in range(2):
            self.encode.append(
                ResBlk(dim_out, dim_out, normalize=True))
            self.decode.insert(
                0, AdainResBlk(dim_out, dim_out, style_dim, w_hpf=w_hpf))

        if w_hpf > 0:
            device = torch.device(
                'cuda' if torch.cuda.is_available() else 'cpu')
            self.hpf = HighPass(w_hpf, device)

    def forward(self, x, s, masks=None):
        x = self.from_rgb(x)
        cache = {}
        for block in self.encode:
            if (masks is not None) and (x.size(2) in [32, 64, 128]):
                cache[x.size(2)] = x
            x = block(x)
        for block in self.decode:
            x = block(x, s)
            if (masks is not None) and (x.size(2) in [32, 64, 128]):
                mask = masks[0] if x.size(2) in [32] else masks[1]
                mask = F.interpolate(mask, size=x.size(2), mode='bilinear')
                x = x + self.hpf(mask * cache[x.size(2)])
        return self.to_rgb(x)


class MappingNetwork(nn.Module):
    def __init__(self, latent_dim=16, style_dim=64, num_domains=2):
        super().__init__()
        layers = []
        layers += [nn.Linear(latent_dim, 512)]
        layers += [nn.ReLU()]
        for _ in range(3):
            layers += [nn.Linear(512, 512)]
            layers += [nn.ReLU()]
        self.shared = nn.Sequential(*layers)

        self.unshared = nn.ModuleList()
        for _ in range(num_domains):
            self.unshared += [nn.Sequential(nn.Linear(512, 512),
                                            nn.ReLU(),
                                            nn.Linear(512, 512),
                                            nn.ReLU(),
                                            nn.Linear(512, 512),
                                            nn.ReLU(),
                                            nn.Linear(512, style_dim))]

    def forward(self, z, y):
        h = self.shared(z)
        out = []
        for layer in self.unshared:
            out += [layer(h)]
        out = torch.stack(out, dim=1)  # (batch, num_domains, style_dim)
        idx = torch.LongTensor(range(y.size(0))).to(y.device)
        s = out[idx, y]  # (batch, style_dim)
        return s


class StyleEncoder(nn.Module):
    def __init__(self, img_size=256, style_dim=64, num_domains=2, max_conv_dim=512):
        super().__init__()
        dim_in = 2**14 // img_size
        blocks = []
        blocks += [nn.Conv2d(3, dim_in, 3, 1, 1)]

        repeat_num = int(np.log2(img_size)) - 2
        for _ in range(repeat_num):
            dim_out = min(dim_in*2, max_conv_dim)
            blocks += [ResBlk(dim_in, dim_out, downsample=True)]
            dim_in = dim_out

        blocks += [nn.LeakyReLU(0.2)]
        blocks += [nn.Conv2d(dim_out, dim_out, 4, 1, 0)]
        blocks += [nn.LeakyReLU(0.2)]
        self.shared = nn.Sequential(*blocks)

        self.unshared = nn.ModuleList()
        for _ in range(num_domains):
            self.unshared += [nn.Linear(dim_out, style_dim)]

    def forward(self, x, y):
        h = self.shared(x)
        h = h.view(h.size(0), -1)
        out = []
        for layer in self.unshared:
            out += [layer(h)]
        out = torch.stack(out, dim=1)  # (batch, num_domains, style_dim)
        idx = torch.LongTensor(range(y.size(0))).to(y.device)
        s = out[idx, y]  # (batch, style_dim)
        return s


class Discriminator(nn.Module):
    def __init__(self, img_size=256, num_domains=2, max_conv_dim=512):
        super().__init__()
        dim_in = 2**14 // img_size
        blocks = []
        blocks += [nn.Conv2d(3, dim_in, 3, 1, 1)]

        repeat_num = int(np.log2(img_size)) - 2
        for _ in range(repeat_num):
            dim_out = min(dim_in*2, max_conv_dim)
            blocks += [ResBlk(dim_in, dim_out, downsample=True)]
            dim_in = dim_out

        blocks += [nn.LeakyReLU(0.2)]
        blocks += [nn.Conv2d(dim_out, dim_out, 4, 1, 0)]
        blocks += [nn.LeakyReLU(0.2)]
        blocks += [nn.Conv2d(dim_out, num_domains, 1, 1, 0)]
        self.main = nn.Sequential(*blocks)

    def forward(self, x, y):
        out = self.main(x)
        out = out.view(out.size(0), -1)  # (batch, num_domains)
        idx = torch.LongTensor(range(y.size(0))).to(y.device)
        out = out[idx, y]  # (batch)
        return out


def build_model(args):
    generator = nn.DataParallel(Generator(args.img_size, args.style_dim, w_hpf=args.w_hpf))
    mapping_network = nn.DataParallel(MappingNetwork(args.latent_dim, args.style_dim, args.num_domains))
    style_encoder = nn.DataParallel(StyleEncoder(args.img_size, args.style_dim, args.num_domains))
    discriminator = nn.DataParallel(Discriminator(args.img_size, args.num_domains))
    generator_ema = copy.deepcopy(generator)
    mapping_network_ema = copy.deepcopy(mapping_network)
    style_encoder_ema = copy.deepcopy(style_encoder)

    nets = Munch(generator=generator,
                 mapping_network=mapping_network,
                 style_encoder=style_encoder,
                 discriminator=discriminator)
    nets_ema = Munch(generator=generator_ema,
                     mapping_network=mapping_network_ema,
                     style_encoder=style_encoder_ema)

    if args.w_hpf > 0:
        fan = nn.DataParallel(FAN(fname_pretrained=args.wing_path).eval())
        fan.get_heatmap = fan.module.get_heatmap
        nets.fan = fan
        nets_ema.fan = fan

    return nets, nets_ema

# %%
#!g1.1
### THIS IS CORE UTILS
def save_json(json_file, filename):
    with open(filename, 'w') as f:
        json.dump(json_file, f, indent=4, sort_keys=False)


def print_network(network, name):
    num_params = 0
    for p in network.parameters():
        num_params += p.numel()
    # print(network)
    print("Number of parameters of %s: %i" % (name, num_params))


def he_init(module):
    if isinstance(module, nn.Conv2d):
        nn.init.kaiming_normal_(module.weight, mode='fan_in', nonlinearity='relu')
        if module.bias is not None:
            nn.init.constant_(module.bias, 0)
    if isinstance(module, nn.Linear):
        nn.init.kaiming_normal_(module.weight, mode='fan_in', nonlinearity='relu')
        if module.bias is not None:
            nn.init.constant_(module.bias, 0)


def denormalize(x):
    out = (x + 1) / 2
    return out.clamp_(0, 1)


def save_image(x, ncol, filename):
    x = denormalize(x)
    vutils.save_image(x.cpu(), filename, nrow=ncol, padding=0)


@torch.no_grad()
def translate_and_reconstruct(nets, args, x_src, y_src, x_ref, y_ref, filename):
    N, C, H, W = x_src.size()
    s_ref = nets.style_encoder(x_ref, y_ref)
    masks = nets.fan.get_heatmap(x_src) if args.w_hpf > 0 else None
    x_fake = nets.generator(x_src, s_ref, masks=masks)
    s_src = nets.style_encoder(x_src, y_src)
    masks = nets.fan.get_heatmap(x_fake) if args.w_hpf > 0 else None
    x_rec = nets.generator(x_fake, s_src, masks=masks)
    x_concat = [x_src, x_ref, x_fake, x_rec]
    x_concat = torch.cat(x_concat, dim=0)
    save_image(x_concat, N, filename)
    del x_concat


@torch.no_grad()
def translate_using_latent(nets, args, x_src, y_trg_list, z_trg_list, psi, filename):
    N, C, H, W = x_src.size()
    latent_dim = z_trg_list[0].size(1)
    x_concat = [x_src]
    masks = nets.fan.get_heatmap(x_src) if args.w_hpf > 0 else None

    for i, y_trg in enumerate(y_trg_list):
        z_many = torch.randn(10000, latent_dim).to(x_src.device)
        y_many = torch.LongTensor(10000).to(x_src.device).fill_(y_trg[0])
        s_many = nets.mapping_network(z_many, y_many)
        s_avg = torch.mean(s_many, dim=0, keepdim=True)
        s_avg = s_avg.repeat(N, 1)

        for z_trg in z_trg_list:
            s_trg = nets.mapping_network(z_trg, y_trg)
            s_trg = torch.lerp(s_avg, s_trg, psi)
            x_fake = nets.generator(x_src, s_trg, masks=masks)
            x_concat += [x_fake]

    x_concat = torch.cat(x_concat, dim=0)
    save_image(x_concat, N, filename)


@torch.no_grad()
def translate_using_reference(nets, args, x_src, x_ref, y_ref, filename):
    N, C, H, W = x_src.size()
    wb = torch.ones(1, C, H, W).to(x_src.device)
    x_src_with_wb = torch.cat([wb, x_src], dim=0)

    masks = nets.fan.get_heatmap(x_src) if args.w_hpf > 0 else None
    s_ref = nets.style_encoder(x_ref, y_ref)
    s_ref_list = s_ref.unsqueeze(1).repeat(1, N, 1)
    x_concat = [x_src_with_wb]
    for i, s_ref in enumerate(s_ref_list):
        x_fake = nets.generator(x_src, s_ref, masks=masks)
        x_fake_with_ref = torch.cat([x_ref[i:i+1], x_fake], dim=0)
        x_concat += [x_fake_with_ref]

    x_concat = torch.cat(x_concat, dim=0)
    save_image(x_concat, N+1, filename)
    del x_concat


@torch.no_grad()
def debug_image(nets, args, inputs, step):
    x_src, y_src = inputs.x_src, inputs.y_src
    x_ref, y_ref = inputs.x_ref, inputs.y_ref

    device = inputs.x_src.device
    N = inputs.x_src.size(0)

    # translate and reconstruct (reference-guided)
    filename = ospj(args.sample_dir, '%06d_cycle_consistency.jpg' % (step))
    translate_and_reconstruct(nets, args, x_src, y_src, x_ref, y_ref, filename)

    # latent-guided image synthesis
    y_trg_list = [torch.tensor(y).repeat(N).to(device)
                  for y in range(min(args.num_domains, 5))]
    z_trg_list = torch.randn(args.num_outs_per_domain, 1, args.latent_dim).repeat(1, N, 1).to(device)
    for psi in [0.5, 0.7, 1.0]:
        filename = ospj(args.sample_dir, '%06d_latent_psi_%.1f.jpg' % (step, psi))
        translate_using_latent(nets, args, x_src, y_trg_list, z_trg_list, psi, filename)

    # reference-guided image synthesis
    filename = ospj(args.sample_dir, '%06d_reference.jpg' % (step))
    translate_using_reference(nets, args, x_src, x_ref, y_ref, filename)


# ======================= #
# Video-related functions #
# ======================= #


def sigmoid(x, w=1):
    return 1. / (1 + np.exp(-w * x))


def get_alphas(start=-5, end=5, step=0.5, len_tail=10):
    return [0] + [sigmoid(alpha) for alpha in np.arange(start, end, step)] + [1] * len_tail


def interpolate(nets, args, x_src, s_prev, s_next):
    ''' returns T x C x H x W '''
    B = x_src.size(0)
    frames = []
    masks = nets.fan.get_heatmap(x_src) if args.w_hpf > 0 else None
    alphas = get_alphas()

    for alpha in alphas:
        s_ref = torch.lerp(s_prev, s_next, alpha)
        x_fake = nets.generator(x_src, s_ref, masks=masks)
        entries = torch.cat([x_src.cpu(), x_fake.cpu()], dim=2)
        frame = torchvision.utils.make_grid(entries, nrow=B, padding=0, pad_value=-1).unsqueeze(0)
        frames.append(frame)
    frames = torch.cat(frames)
    return frames


def slide(entries, margin=32):
    """Returns a sliding reference window.
    Args:
        entries: a list containing two reference images, x_prev and x_next, 
                 both of which has a shape (1, 3, 256, 256)
    Returns:
        canvas: output slide of shape (num_frames, 3, 256*2, 256+margin)
    """
    _, C, H, W = entries[0].shape
    alphas = get_alphas()
    T = len(alphas) # number of frames

    canvas = - torch.ones((T, C, H*2, W + margin))
    merged = torch.cat(entries, dim=2)  # (1, 3, 512, 256)
    for t, alpha in enumerate(alphas):
        top = int(H * (1 - alpha))  # top, bottom for canvas
        bottom = H * 2
        m_top = 0  # top, bottom for merged
        m_bottom = 2 * H - top
        canvas[t, :, top:bottom, :W] = merged[:, :, m_top:m_bottom, :]
    return canvas


@torch.no_grad()
def video_ref(nets, args, x_src, x_ref, y_ref, fname):
    video = []
    s_ref = nets.style_encoder(x_ref, y_ref)
    s_prev = None
    for data_next in tqdm(zip(x_ref, y_ref, s_ref), 'video_ref', len(x_ref)):
        x_next, y_next, s_next = [d.unsqueeze(0) for d in data_next]
        if s_prev is None:
            x_prev, y_prev, s_prev = x_next, y_next, s_next
            continue
        if y_prev != y_next:
            x_prev, y_prev, s_prev = x_next, y_next, s_next
            continue

        interpolated = interpolate(nets, args, x_src, s_prev, s_next)
        entries = [x_prev, x_next]
        slided = slide(entries)  # (T, C, 256*2, 256)
        frames = torch.cat([slided, interpolated], dim=3).cpu()  # (T, C, 256*2, 256*(batch+1))
        video.append(frames)
        x_prev, y_prev, s_prev = x_next, y_next, s_next

    # append last frame 10 time
    for _ in range(10):
        video.append(frames[-1:])
    video = tensor2ndarray255(torch.cat(video))
    save_video(fname, video)


@torch.no_grad()
def video_latent(nets, args, x_src, y_list, z_list, psi, fname):
    latent_dim = z_list[0].size(1)
    s_list = []
    for i, y_trg in enumerate(y_list):
        z_many = torch.randn(10000, latent_dim).to(x_src.device)
        y_many = torch.LongTensor(10000).to(x_src.device).fill_(y_trg[0])
        s_many = nets.mapping_network(z_many, y_many)
        s_avg = torch.mean(s_many, dim=0, keepdim=True)
        s_avg = s_avg.repeat(x_src.size(0), 1)

        for z_trg in z_list:
            s_trg = nets.mapping_network(z_trg, y_trg)
            s_trg = torch.lerp(s_avg, s_trg, psi)
            s_list.append(s_trg)

    s_prev = None
    video = []
    # fetch reference images
    for idx_ref, s_next in enumerate(tqdm(s_list, 'video_latent', len(s_list))):
        if s_prev is None:
            s_prev = s_next
            continue
        if idx_ref % len(z_list) == 0:
            s_prev = s_next
            continue
        frames = interpolate(nets, args, x_src, s_prev, s_next).cpu()
        video.append(frames)
        s_prev = s_next
    for _ in range(10):
        video.append(frames[-1:])
    video = tensor2ndarray255(torch.cat(video))
    save_video(fname, video)


def save_video(fname, images, output_fps=30, vcodec='libx264', filters=''):
    assert isinstance(images, np.ndarray), "images should be np.array: NHWC"
    num_frames, height, width, channels = images.shape
    stream = ffmpeg.input('pipe:', format='rawvideo', 
                          pix_fmt='rgb24', s='{}x{}'.format(width, height))
    stream = ffmpeg.filter(stream, 'setpts', '2*PTS')  # 2*PTS is for slower playback
    stream = ffmpeg.output(stream, fname, pix_fmt='yuv420p', vcodec=vcodec, r=output_fps)
    stream = ffmpeg.overwrite_output(stream)
    process = ffmpeg.run_async(stream, pipe_stdin=True)
    for frame in tqdm(images, desc='writing video to %s' % fname):
        process.stdin.write(frame.astype(np.uint8).tobytes())
    process.stdin.close()
    process.wait()


def tensor2ndarray255(images):
    images = torch.clamp(images * 0.5 + 0.5, 0, 1)
    return images.cpu().numpy().transpose(0, 2, 3, 1) * 255

# %%
#!g1.1
### THIS IS CORE CHECKPOINT
class CheckpointIO(object):
    def __init__(self, fname_template, data_parallel=False, **kwargs):
        os.makedirs(os.path.dirname(fname_template), exist_ok=True)
        self.fname_template = fname_template
        self.module_dict = kwargs
        self.data_parallel = data_parallel

    def register(self, **kwargs):
        self.module_dict.update(kwargs)

    def save(self, step):
#         fname = self.fname_template.format(step)
        fname = self.fname_template
        print('Saving checkpoint into %s...' % fname)
        outdict = {}
        for name, module in self.module_dict.items():
            if self.data_parallel:
                outdict[name] = module.module.state_dict()
            else:
                outdict[name] = module.state_dict()
                        
        torch.save(outdict, fname)

    def load(self, step):
        fname = self.fname_template.format(step)
        assert os.path.exists(fname), fname + ' does not exist!'
        print('Loading checkpoint from %s...' % fname)
        if torch.cuda.is_available():
            module_dict = torch.load(fname)
        else:
            module_dict = torch.load(fname, map_location=torch.device('cpu'))
            
        for name, module in self.module_dict.items():
            if self.data_parallel:
                module.module.load_state_dict(module_dict[name])
            else:
                module.load_state_dict(module_dict[name])

# %%
#!g1.1
from torchvision import models

def normalize(x, eps=1e-10):
    return x * torch.rsqrt(torch.sum(x**2, dim=1, keepdim=True) + eps)


class AlexNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = models.alexnet(pretrained=True).features
        self.channels = []
        for layer in self.layers:
            if isinstance(layer, nn.Conv2d):
                self.channels.append(layer.out_channels)

    def forward(self, x):
        fmaps = []
        for layer in self.layers:
            x = layer(x)
            if isinstance(layer, nn.ReLU):
                fmaps.append(x)
        return fmaps


class Conv1x1(nn.Module):
    def __init__(self, in_channels, out_channels=1):
        super().__init__()
        self.main = nn.Sequential(
            nn.Dropout(0.5),
            nn.Conv2d(in_channels, out_channels, 1, 1, 0, bias=False))

    def forward(self, x):
        return self.main(x)


class LPIPS(nn.Module):
    def __init__(self):
        super().__init__()
        self.alexnet = AlexNet()
        self.lpips_weights = nn.ModuleList()
        for channels in self.alexnet.channels:
            self.lpips_weights.append(Conv1x1(channels, 1))
        self._load_lpips_weights()
        # imagenet normalization for range [-1, 1]
        self.mu = torch.tensor([-0.03, -0.088, -0.188]).view(1, 3, 1, 1).cuda()
        self.sigma = torch.tensor([0.458, 0.448, 0.450]).view(1, 3, 1, 1).cuda()

    def _load_lpips_weights(self):
        own_state_dict = self.state_dict()
        if torch.cuda.is_available():
            state_dict = torch.load('lpips_weights.ckpt')
        else:
            state_dict = torch.load('lpips_weights.ckpt',
                                    map_location=torch.device('cpu'))
        for name, param in state_dict.items():
            if name in own_state_dict:
                own_state_dict[name].copy_(param)

    def forward(self, x, y):
        x = (x - self.mu) / self.sigma
        y = (y - self.mu) / self.sigma
        x_fmaps = self.alexnet(x)
        y_fmaps = self.alexnet(y)
        lpips_value = 0
        for x_fmap, y_fmap, conv1x1 in zip(x_fmaps, y_fmaps, self.lpips_weights):
            x_fmap = normalize(x_fmap)
            y_fmap = normalize(y_fmap)
            lpips_value += torch.mean(conv1x1((x_fmap - y_fmap)**2))
        return lpips_value


@torch.no_grad()
def calculate_lpips_given_images(group_of_images):
    # group_of_images = [torch.randn(N, C, H, W) for _ in range(10)]
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    lpips = LPIPS().eval().to(device)
    lpips_values = []
    num_rand_outputs = len(group_of_images)

    # calculate the average of pairwise distances among all random outputs
    for i in range(num_rand_outputs-1):
        for j in range(i+1, num_rand_outputs):
            lpips_values.append(lpips(group_of_images[i], group_of_images[j]))
    lpips_value = torch.mean(torch.stack(lpips_values, dim=0))
    return lpips_value.item()

# %%
#!g1.1
from scipy import linalg


class InceptionV3(nn.Module):
    def __init__(self):
        super().__init__()
        inception = models.inception_v3(pretrained=True)
        self.block1 = nn.Sequential(
            inception.Conv2d_1a_3x3, inception.Conv2d_2a_3x3,
            inception.Conv2d_2b_3x3,
            nn.MaxPool2d(kernel_size=3, stride=2))
        self.block2 = nn.Sequential(
            inception.Conv2d_3b_1x1, inception.Conv2d_4a_3x3,
            nn.MaxPool2d(kernel_size=3, stride=2))
        self.block3 = nn.Sequential(
            inception.Mixed_5b, inception.Mixed_5c,
            inception.Mixed_5d, inception.Mixed_6a,
            inception.Mixed_6b, inception.Mixed_6c,
            inception.Mixed_6d, inception.Mixed_6e)
        self.block4 = nn.Sequential(
            inception.Mixed_7a, inception.Mixed_7b,
            inception.Mixed_7c,
            nn.AdaptiveAvgPool2d(output_size=(1, 1)))

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        return x.view(x.size(0), -1)


def frechet_distance(mu, cov, mu2, cov2):
    cc, _ = linalg.sqrtm(np.dot(cov, cov2), disp=False)
    dist = np.sum((mu -mu2)**2) + np.trace(cov + cov2 - 2*cc)
    return np.real(dist)


@torch.no_grad()
def calculate_fid_given_paths(paths, img_size=256, batch_size=50):
    print('Calculating FID given paths %s and %s...' % (paths[0], paths[1]))
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    inception = InceptionV3().eval().to(device)
    loaders = [get_eval_loader(path, img_size, batch_size) for path in paths]

    mu, cov = [], []
    for loader in loaders:
        actvs = []
        for x in tqdm(loader, total=len(loader)):
            actv = inception(x.to(device))
            actvs.append(actv)
        actvs = torch.cat(actvs, dim=0).cpu().detach().numpy()
        mu.append(np.mean(actvs, axis=0))
        cov.append(np.cov(actvs, rowvar=False))
    fid_value = frechet_distance(mu[0], cov[0], mu[1], cov[1])
    return fid_value

# %%
#!g1.1
import os
import shutil
from collections import OrderedDict
from tqdm import tqdm

import numpy as np
import torch


@torch.no_grad()
def calculate_metrics(nets, args, step, mode):
    print('Calculating evaluation metrics...')
    assert mode in ['latent', 'reference']
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    domains = os.listdir(args.val_img_dir)
    domains.sort()
    num_domains = len(domains)
    print('Number of domains: %d' % num_domains)

    lpips_dict = OrderedDict()
    for trg_idx, trg_domain in enumerate(domains):
        src_domains = [x for x in domains if x != trg_domain]

        if mode == 'reference':
            path_ref = os.path.join(args.val_img_dir, trg_domain)
            loader_ref = get_eval_loader(root=path_ref,
                                         img_size=args.img_size,
                                         batch_size=args.val_batch_size,
                                         imagenet_normalize=False,
                                         drop_last=True)

        for src_idx, src_domain in enumerate(src_domains):
            path_src = os.path.join(args.val_img_dir, src_domain)
            loader_src = get_eval_loader(root=path_src,
                                         img_size=args.img_size,
                                         batch_size=args.val_batch_size,
                                         imagenet_normalize=False)

            task = '%s2%s' % (src_domain, trg_domain)
            path_fake = os.path.join(args.eval_dir, task)
            shutil.rmtree(path_fake, ignore_errors=True)
            os.makedirs(path_fake)

            lpips_values = []
            print('Generating images and calculating LPIPS for %s...' % task)
            for i, x_src in enumerate(tqdm(loader_src, total=len(loader_src))):
                N = x_src.size(0)
                x_src = x_src.to(device)
                y_trg = torch.tensor([trg_idx] * N).to(device)
                masks = nets.fan.get_heatmap(x_src) if args.w_hpf > 0 else None

                # generate 10 outputs from the same input
                group_of_images = []
                for j in range(args.num_outs_per_domain):
                    if mode == 'latent':
                        z_trg = torch.randn(N, args.latent_dim).to(device)
                        s_trg = nets.mapping_network(z_trg, y_trg)
                    else:
                        try:
                            x_ref = next(iter_ref).to(device)
                        except:
                            iter_ref = iter(loader_ref)
                            x_ref = next(iter_ref).to(device)

                        if x_ref.size(0) > N:
                            x_ref = x_ref[:N]
                        s_trg = nets.style_encoder(x_ref, y_trg)

                    x_fake = nets.generator(x_src, s_trg, masks=masks)
                    group_of_images.append(x_fake)

                    # save generated images to calculate FID later
                    for k in range(N):
                        filename = os.path.join(
                            path_fake,
                            '%.4i_%.2i.png' % (i*args.val_batch_size+(k+1), j+1))
                        save_image(x_fake[k], ncol=1, filename=filename)

                lpips_value = calculate_lpips_given_images(group_of_images)
                lpips_values.append(lpips_value)

            # calculate LPIPS for each task (e.g. cat2dog, dog2cat)
            lpips_mean = np.array(lpips_values).mean()
            lpips_dict['LPIPS_%s/%s' % (mode, task)] = lpips_mean

        # delete dataloaders
        del loader_src
        if mode == 'reference':
            del loader_ref
            del iter_ref

    # calculate the average LPIPS for all tasks
    lpips_mean = 0
    for _, value in lpips_dict.items():
        lpips_mean += value / len(lpips_dict)
    lpips_dict['LPIPS_%s/mean' % mode] = lpips_mean

    # report LPIPS values
    filename = os.path.join(args.eval_dir, 'LPIPS_%.5i_%s.json' % (step, mode))
    save_json(lpips_dict, filename)

    # calculate and report fid values
    calculate_fid_for_all_tasks(args, domains, step=step, mode=mode)


def calculate_fid_for_all_tasks(args, domains, step, mode):
    print('Calculating FID for all tasks...')
    fid_values = OrderedDict()
    for trg_domain in domains:
        src_domains = [x for x in domains if x != trg_domain]

        for src_domain in src_domains:
            task = '%s2%s' % (src_domain, trg_domain)
            path_real = os.path.join(args.train_img_dir, trg_domain)
            path_fake = os.path.join(args.eval_dir, task)
            print('Calculating FID for %s...' % task)
            fid_value = calculate_fid_given_paths(
                paths=[path_real, path_fake],
                img_size=args.img_size,
                batch_size=args.val_batch_size)
            fid_values['FID_%s/%s' % (mode, task)] = fid_value

    # calculate the average FID for all tasks
    fid_mean = 0
    for _, value in fid_values.items():
        fid_mean += value / len(fid_values)
    fid_values['FID_%s/mean' % mode] = fid_mean

    # report FID values
    filename = os.path.join(args.eval_dir, 'FID_%.5i_%s.json' % (step, mode))
    save_json(fid_values, filename)

# %%
#!g1.1

class Solver(nn.Module):
    def __init__(self, args):
        super().__init__()
        self.args = args
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        self.nets, self.nets_ema = build_model(args)
        # below setattrs are to make networks be children of Solver, e.g., for self.to(self.device)
        for name, module in self.nets.items():
            print_network(module, name)
            setattr(self, name, module)
        for name, module in self.nets_ema.items():
            setattr(self, name + '_ema', module)

        if args.mode == 'train':
            self.optims = Munch()
            for net in self.nets.keys():
                if net == 'fan':
                    continue
                self.optims[net] = torch.optim.Adam(
                    params=self.nets[net].parameters(),
                    lr=args.f_lr if net == 'mapping_network' else args.lr,
                    betas=[args.beta1, args.beta2],
                    weight_decay=args.weight_decay)

            self.ckptios = [
                CheckpointIO(ospj(args.checkpoint_dir, 'nets.ckpt'), data_parallel=True, **self.nets),
                CheckpointIO(ospj(args.checkpoint_dir, 'nets_ema.ckpt'), data_parallel=True, **self.nets_ema),
                CheckpointIO(ospj(args.checkpoint_dir, 'optims.ckpt'), **self.optims)]
#                 CheckpointIO(ospj(args.checkpoint_dir, '{:06d}_nets.ckpt'), data_parallel=True, **self.nets),
#                 CheckpointIO(ospj(args.checkpoint_dir, '{:06d}_nets_ema.ckpt'), data_parallel=True, **self.nets_ema),
#                 CheckpointIO(ospj(args.checkpoint_dir, '{:06d}_optims.ckpt'), **self.optims)]
        else:
            self.ckptios = [CheckpointIO(ospj(args.checkpoint_dir, 'nets_ema.ckpt'), data_parallel=True, **self.nets_ema)]
#             self.ckptios = [CheckpointIO(ospj(args.checkpoint_dir, '{:06d}_nets_ema.ckpt'), data_parallel=True, **self.nets_ema)]

        self.to(self.device)
        for name, network in self.named_children():
            # Do not initialize the FAN parameters
            if ('ema' not in name) and ('fan' not in name):
                print('Initializing %s...' % name)
                network.apply(he_init)

    def _save_checkpoint(self, step):
        for ckptio in self.ckptios:
            ckptio.save(step)

    def _load_checkpoint(self, step):
        for ckptio in self.ckptios:
            ckptio.load(step)

    def _reset_grad(self):
        for optim in self.optims.values():
            optim.zero_grad()

    def train(self, loaders):
        args = self.args
        nets = self.nets
        nets_ema = self.nets_ema
        optims = self.optims

        # fetch random validation images for debugging
        fetcher = InputFetcher(loaders.src, loaders.ref, args.latent_dim, 'train')
        fetcher_val = InputFetcher(loaders.val, None, args.latent_dim, 'val')
        inputs_val = next(fetcher_val)

        # resume training if necessary
        if args.resume_iter > 0:
            self._load_checkpoint(args.resume_iter)

        # remember the initial value of ds weight
        initial_lambda_ds = args.lambda_ds

        print('Start training...')
        start_time = time.time()
        for i in range(args.resume_iter, args.total_iters):
            # fetch images and labels
            inputs = next(fetcher)
            x_real, y_org = inputs.x_src, inputs.y_src
            x_ref, x_ref2, y_trg = inputs.x_ref, inputs.x_ref2, inputs.y_ref
            z_trg, z_trg2 = inputs.z_trg, inputs.z_trg2

            masks = nets.fan.get_heatmap(x_real) if args.w_hpf > 0 else None

            # train the discriminator
            d_loss, d_losses_latent = compute_d_loss(
                nets, args, x_real, y_org, y_trg, z_trg=z_trg, masks=masks)
            self._reset_grad()
            d_loss.backward()
            optims.discriminator.step()

            d_loss, d_losses_ref = compute_d_loss(
                nets, args, x_real, y_org, y_trg, x_ref=x_ref, masks=masks)
            self._reset_grad()
            d_loss.backward()
            optims.discriminator.step()

            # train the generator
            g_loss, g_losses_latent = compute_g_loss(
                nets, args, x_real, y_org, y_trg, z_trgs=[z_trg, z_trg2], masks=masks)
            self._reset_grad()
            g_loss.backward()
            optims.generator.step()
            optims.mapping_network.step()
            optims.style_encoder.step()

            g_loss, g_losses_ref = compute_g_loss(
                nets, args, x_real, y_org, y_trg, x_refs=[x_ref, x_ref2], masks=masks)
            self._reset_grad()
            g_loss.backward()
            optims.generator.step()

            # compute moving average of network parameters
            moving_average(nets.generator, nets_ema.generator, beta=0.999)
            moving_average(nets.mapping_network, nets_ema.mapping_network, beta=0.999)
            moving_average(nets.style_encoder, nets_ema.style_encoder, beta=0.999)

            # decay weight for diversity sensitive loss
            if args.lambda_ds > 0:
                args.lambda_ds -= (initial_lambda_ds / args.ds_iter)

            # print out log info
            if (i+1) % args.print_every == 0:
                elapsed = time.time() - start_time
                elapsed = str(datetime.timedelta(seconds=elapsed))[:-7]
                log = "Elapsed time [%s], Iteration [%i/%i], " % (elapsed, i+1, args.total_iters)
                all_losses = dict()
                for loss, prefix in zip([d_losses_latent, d_losses_ref, g_losses_latent, g_losses_ref],
                                        ['D/latent_', 'D/ref_', 'G/latent_', 'G/ref_']):
                    for key, value in loss.items():
                        all_losses[prefix + key] = value
                all_losses['G/lambda_ds'] = args.lambda_ds
                log += ' '.join(['%s: [%.4f]' % (key, value) for key, value in all_losses.items()])
                print(log)

            # generate images for debugging
            if (i+1) % args.sample_every == 0:
                os.makedirs(args.sample_dir, exist_ok=True)
                debug_image(nets_ema, args, inputs=inputs_val, step=i+1)

            # save model checkpoints
            if (i+1) % args.save_every == 0:
                self._save_checkpoint(step=i+1)

            # compute FID and LPIPS if necessary
#             if (i+1) % args.eval_every == 0:
#                 calculate_metrics(nets_ema, args, i+1, mode='latent')
#                 calculate_metrics(nets_ema, args, i+1, mode='reference')

    @torch.no_grad()
    def sample(self, loaders):
        args = self.args
        nets_ema = self.nets_ema
        os.makedirs(args.result_dir, exist_ok=True)
        self._load_checkpoint(args.resume_iter)

        src = next(InputFetcher(loaders.src, None, args.latent_dim, 'test'))
        ref = next(InputFetcher(loaders.ref, None, args.latent_dim, 'test'))

        fname = ospj(args.result_dir, 'reference.jpg')
        print('Working on {}...'.format(fname))
        translate_using_reference(nets_ema, args, src.x, ref.x, ref.y, fname)

        fname = ospj(args.result_dir, 'video_ref.mp4')
        print('Working on {}...'.format(fname))
        video_ref(nets_ema, args, src.x, ref.x, ref.y, fname)

    @torch.no_grad()
    def evaluate(self):
        args = self.args
        nets_ema = self.nets_ema
        resume_iter = args.resume_iter
        self._load_checkpoint(args.resume_iter)
#         calculate_metrics(nets_ema, args, step=resume_iter, mode='latent')
#         calculate_metrics(nets_ema, args, step=resume_iter, mode='reference')


def compute_d_loss(nets, args, x_real, y_org, y_trg, z_trg=None, x_ref=None, masks=None):
    assert (z_trg is None) != (x_ref is None)
    # with real images
    x_real.requires_grad_()
    out = nets.discriminator(x_real, y_org)
    loss_real = adv_loss(out, 1)
    loss_reg = r1_reg(out, x_real)

    # with fake images
    with torch.no_grad():
        if z_trg is not None:
            s_trg = nets.mapping_network(z_trg, y_trg)
        else:  # x_ref is not None
            s_trg = nets.style_encoder(x_ref, y_trg)

        x_fake = nets.generator(x_real, s_trg, masks=masks)
    out = nets.discriminator(x_fake, y_trg)
    loss_fake = adv_loss(out, 0)

    loss = loss_real + loss_fake + args.lambda_reg * loss_reg
    return loss, Munch(real=loss_real.item(),
                       fake=loss_fake.item(),
                       reg=loss_reg.item())


def compute_g_loss(nets, args, x_real, y_org, y_trg, z_trgs=None, x_refs=None, masks=None):
    assert (z_trgs is None) != (x_refs is None)
    if z_trgs is not None:
        z_trg, z_trg2 = z_trgs
    if x_refs is not None:
        x_ref, x_ref2 = x_refs

    # adversarial loss
    if z_trgs is not None:
        s_trg = nets.mapping_network(z_trg, y_trg)
    else:
        s_trg = nets.style_encoder(x_ref, y_trg)

    x_fake = nets.generator(x_real, s_trg, masks=masks)
    out = nets.discriminator(x_fake, y_trg)
    loss_adv = adv_loss(out, 1)

    # style reconstruction loss
    s_pred = nets.style_encoder(x_fake, y_trg)
    loss_sty = torch.mean(torch.abs(s_pred - s_trg))

    # diversity sensitive loss
    if z_trgs is not None:
        s_trg2 = nets.mapping_network(z_trg2, y_trg)
    else:
        s_trg2 = nets.style_encoder(x_ref2, y_trg)
    x_fake2 = nets.generator(x_real, s_trg2, masks=masks)
    x_fake2 = x_fake2.detach()
    loss_ds = torch.mean(torch.abs(x_fake - x_fake2))

    # cycle-consistency loss
    masks = nets.fan.get_heatmap(x_fake) if args.w_hpf > 0 else None
    s_org = nets.style_encoder(x_real, y_org)
    x_rec = nets.generator(x_fake, s_org, masks=masks)
    loss_cyc = torch.mean(torch.abs(x_rec - x_real))

    loss = loss_adv + args.lambda_sty * loss_sty \
        - args.lambda_ds * loss_ds + args.lambda_cyc * loss_cyc
    return loss, Munch(adv=loss_adv.item(),
                       sty=loss_sty.item(),
                       ds=loss_ds.item(),
                       cyc=loss_cyc.item())


def moving_average(model, model_test, beta=0.999):
    for param, param_test in zip(model.parameters(), model_test.parameters()):
        param_test.data = torch.lerp(param.data, param_test.data, beta)


def adv_loss(logits, target):
    assert target in [1, 0]
    targets = torch.full_like(logits, fill_value=target)
    loss = F.binary_cross_entropy_with_logits(logits, targets)
    return loss


def r1_reg(d_out, x_in):
    # zero-centered gradient penalty for real images
    batch_size = x_in.size(0)
    grad_dout = torch.autograd.grad(
        outputs=d_out.sum(), inputs=x_in,
        create_graph=True, retain_graph=True, only_inputs=True
    )[0]
    grad_dout2 = grad_dout.pow(2)
    assert(grad_dout2.size() == x_in.size())
    reg = 0.5 * grad_dout2.view(batch_size, -1).sum(1).mean(0)
    return reg

# %%
#!g1.1
loaders = Munch(src=get_train_loader(files=files,
                                     labels=labels,
                                     which='source',
                                     img_size=256,
                                     batch_size=8,
                                     prob=0.5,
                                     num_workers=4),
                ref=get_train_loader(files=files,
                                     labels=labels,
                                     which='reference',
                                     img_size=256,
                                     batch_size=8,
                                     prob=0.5,
                                     num_workers=4),
                val=get_test_loader(files=files,
                                    labels=labels,
                                    img_size=256,
                                    batch_size=8,
                                    shuffle=True,
                                    num_workers=4))
# Out:
# Preparing DataLoader to fetch source images during the training phase...
# Preparing DataLoader to fetch reference images during the training phase...
# NUM DOMAINS = 3
# Preparing DataLoader for the generation phase...

# %%
#!g1.1
args = Munch(
    img_size=256,
    num_domains=labels.max() + 1,
    latent_dim=16,
    hidden_dim=512,
    style_dim=64,
    lambda_reg=1,
    lambda_cyc=1.5,
    lambda_sty=1,
    lambda_ds=0.1,
    ds_iter=100_000,
    w_hpf=0,
    randcrop_prob=0.5,
    total_iters=100_000,
    resume_iter=27_000,
    batch_size=16,
    val_batch_size=32,
    lr=1e-4,
    f_lr=1e-6,
    beta1=0.0,
    beta2=0.99,
    weight_decay=1e-4,
    num_outs_per_domain=10,
    mode='train',
    val_img_dir=None,  ### xz
    sample_dir='expr/samples',
    checkpoint_dir='expr/checkpoints',
    eval_dir='expr/eval',   ### xz
    result_dir='expr/results',
    src_dir=None,   ### xz
    ref_dir=None,   ### xz
    inp_dir=None,   ### xz
    out_dir=None,   ### xz
    wing_path=None, # xz
    lm_path=None, # xz
    print_every=20,
    sample_every=1_000,
    save_every=1_000,
    eval_every=50_000
)

# %%
#!g1.1
solver = Solver(args)
# Out:
# Number of parameters of generator: 33892995
# Number of parameters of mapping_network: 3259072
# Number of parameters of style_encoder: 20949760
# Number of parameters of discriminator: 20852803
# Initializing generator...
# Initializing mapping_network...
# Initializing style_encoder...
# Initializing discriminator...

# %%
#!g1.1
solver.train(loaders)
# Out:
# 1424] G/ref_adv: [3.0786] G/ref_sty: [0.3550] G/ref_ds: [0.3747] G/ref_cyc: [0.1513] G/lambda_ds: [0.0529]
# Elapsed time [1 day, 10:20:42], Iteration [74140/100000], D/latent_real: [0.4363] D/latent_fake: [0.2717] D/latent_reg: [0.1047] D/ref_real: [0.2559] D/ref_fake: [0.0869] D/ref_reg: [0.0732] G/latent_adv: [2.6135] G/latent_sty: [0.1553] G/latent_ds: [0.0548] G/latent_cyc: [0.1404] G/ref_adv: [3.4118] G/ref_sty: [0.4150] G/ref_ds: [0.4051] G/ref_cyc: [0.1465] G/lambda_ds: [0.0529]
# Elapsed time [1 day, 10:21:34], Iteration [74160/100000], D/latent_real: [0.2072] D/latent_fake: [0.2183] D/latent_reg: [0.0935] D/ref_real: [0.0307] D/ref_fake: [0.1539] D/ref_reg: [0.0898] G/latent_adv: [3.7644] G/latent_sty: [0.1526] G/latent_ds: [0.0745] G/latent_cyc: [0.1593] G/ref_adv: [4.4537] G/ref_sty: [0.3749] G/ref_ds: [0.4038] G/ref_cyc: [0.1693] G/lambda_ds: [0.0528]
# Elapsed time [1 day, 10:22:26], Iteration [74180/100000], D/latent_real: [0.3355] D/latent_fake: [0.2372] D/latent_reg: [0.1066] D/ref_real: [0.3464] D/ref_fake: [0.1307] D/ref_reg: [0.0817] G/latent_adv: [2.2974] G/latent_sty: [0.1485] G/latent_ds: [0.0711] G/latent_cyc: [0.1438] G/ref_adv: [2.6868] G/ref_sty: [0.2497] G/ref_ds: [0.3724] G/ref_cyc: [0.1610] G/lambda_ds: [0.0528]
# Elapsed time [1 day, 10:23:18], Iteration [74200/100000], D/latent_real: [0.1517] D/latent_fake: [0.2887] D/latent_reg: [0.0887] D/ref_real: [0.0394] D/ref_fake: [0.0694] D/ref_reg: [0.0796] G/latent_adv: [3.3892] G/latent_sty: [0.1391] G/latent_ds: [0.0658] G/latent_cyc: [0.1807] G/ref_adv: [3.3057] G/ref_sty: [0.4124] G/ref_ds: [0.3373] G/ref_cyc: [0.1690] G/lambda_ds: [0.0528]
# Elapsed time [1 day, 10:24:10], Iteration [74220/100000], D/latent_real: [0.0727] D/latent_fake: [0.3707] D/latent_reg: [0.0487] D/ref_real: [0.3346] D/ref_fake: [0.0860] D/ref_reg: [0.0543] G/latent_adv: [2.6128] G/latent_sty: [0.1541] G/latent_ds: [0.0641] G/latent_cyc: [0.1577] G/ref_adv: [2.6506] G/ref_sty: [0.3787] G/ref_ds: [0.2487] G/ref_cyc: [0.1785] G/lambda_ds: [0.0528]
# Elapsed time [1 day, 10:25:01], Iteration [74240/100000], D/latent_real: [0.1123] D/latent_fake: [0.3633] D/latent_reg: [0.1015] D/ref_real: [0.2759] D/ref_fake: [0.0375] D/ref_reg: [0.0929] G/latent_adv: [3.2588] G/latent_sty: [0.1167] G/latent_ds: [0.0478] G/latent_cyc: [0.1367] G/ref_adv: [3.2473] G/ref_sty: [0.3538] G/ref_ds: [0.3701] G/ref_cyc: [0.1368] G/lambda_ds: [0.0528]
# Elapsed time [1 day, 10:25:53], Iteration [74260/100000], D/latent_real: [0.4061] D/latent_fake: [0.7699] D/latent_reg: [0.1130] D/ref_real: [0.8282] D/ref_fake: [0.0704] D/ref_reg: [0.0693] G/latent_adv: [1.7374] G/latent_sty: [0.1668] G/latent_ds: [0.0382] G/latent_cyc: [0.1294] G/ref_adv: [2.3406] G/ref_sty: [0.4251] G/ref_ds: [0.3327] G/ref_cyc: [0.1436] G/lambda_ds: [0.0527]
# Elapsed time [1 day, 10:26:45], Iteration [74280/100000], D/latent_real: [0.2048] D/latent_fake: [0.3577] D/latent_reg: [0.0677] D/ref_real: [0.1386] D/ref_fake: [0.0716] D/ref_reg: [0.0677] G/latent_adv: [3.0597] G/latent_sty: [0.1589] G/latent_ds: [0.0644] G/latent_cyc: [0.1546] G/ref_adv: [3.0063] G/ref_sty: [0.4431] G/ref_ds: [0.3632] G/ref_cyc: [0.1787] G/lambda_ds: [0.0527]
# Elapsed time [1 day, 10:27:37], Iteration [74300/100000], D/latent_real: [0.1419] D/latent_fake: [0.1498] D/latent_reg: [0.0780] D/ref_real: [0.0331] D/ref_fake: [0.0817] D/ref_reg: [0.0773] G/latent_adv: [3.2875] G/latent_sty: [0.1500] G/latent_ds: [0.0921] G/latent_cyc: [0.1690] G/ref_adv: [3.7052] G/ref_sty: [0.3872] G/ref_ds: [0.2991] G/ref_cyc: [0.1815] G/lambda_ds: [0.0527]
# Elapsed time [1 day, 10:28:29], Iteration [74320/100000], D/latent_real: [0.2749] D/latent_fake: [0.2290] D/latent_reg: [0.0570] D/ref_real: [0.0562] D/ref_fake: [0.1564] D/ref_reg: [0.0533] G/latent_adv: [2.9454] G/latent_sty: [0.1409] G/latent_ds: [0.0796] G/latent_cyc: [0.1755] G/ref_adv: [3.4765] G/ref_sty: [0.4126] G/ref_ds: [0.3603] G/ref_cyc: [0.1594] G/lambda_ds: [0.0527]
# Elapsed time [1 day, 10:29:21], Iteration [74340/100000], D/latent_real: [0.3034] D/latent_fake: [0.3314] D/latent_reg: [0.0728] D/ref_real: [0.0616] D/ref_fake: [0.1575] D/ref_reg: [0.0721] G/latent_adv: [3.4178] G/latent_sty: [0.1656] G/latent_ds: [0.0858] G/latent_cyc: [0.1560] G/ref_adv: [3.1817] G/ref_sty: [0.3202] G/ref_ds: [0.3599] G/ref_cyc: [0.1705] G/lambda_ds: [0.0527]
# Elapsed time [1 day, 10:30:13], Iteration [74360/100000], D/latent_real: [0.3743] D/latent_fake: [0.1123] D/latent_reg: [0.0986] D/ref_real: [0.0266] D/ref_fake: [0.1284] D/ref_reg: [0.0640] G/latent_adv: [3.2485] G/latent_sty: [0.1594] G/latent_ds: [0.1191] G/latent_cyc: [0.1806] G/ref_adv: [3.8596] G/ref_sty: [0.3974] G/ref_ds: [0.3735] G/ref_cyc: [0.1777] G/lambda_ds: [0.0526]
# Elapsed time [1 day, 10:31:04], Iteration [74380/100000], D/latent_real: [0.5392] D/latent_fake: [0.1666] D/latent_reg: [0.0921] D/ref_real: [0.0136] D/ref_fake: [0.1828] D/ref_reg: [0.0551] G/latent_adv: [2.9258] G/latent_sty: [0.1619] G/latent_ds: [0.0477] G/latent_cyc: [0.1315] G/ref_adv: [4.2460] G/ref_sty: [0.4493] G/ref_ds: [0.3697] G/ref_cyc: [0.1261] G/lambda_ds: [0.0526]
# Elapsed time [1 day, 10:31:56], Iteration [74400/100000], D/latent_real: [0.1701] D/latent_fake: [0.2209] D/latent_reg: [0.0676] D/ref_real: [0.1942] D/ref_fake: [0.0723] D/ref_reg: [0.0602] G/latent_adv: [2.2554] G/latent_sty: [0.1849] G/latent_ds: [0.1225] G/latent_cyc: [0.1717] G/ref_adv: [3.1317] G/ref_sty: [0.4983] G/ref_ds: [0.3130] G/ref_cyc: [0.1603] G/lambda_ds: [0.0526]
# Elapsed time [1 day, 10:32:48], Iteration [74420/100000], D/latent_real: [0.1128] D/latent_fake: [0.2983] D/latent_reg: [0.0797] D/ref_real: [0.1672] D/ref_fake: [0.0414] D/ref_reg: [0.0888] G/latent_adv: [3.4313] G/latent_sty: [0.1492] G/latent_ds: [0.0709] G/latent_cyc: [0.1459] G/ref_adv: [3.2002] G/ref_sty: [0.4033] G/ref_ds: [0.3661] G/ref_cyc: [0.1172] G/lambda_ds: [0.0526]
# Elapsed time [1 day, 10:33:40], Iteration [74440/100000], D/latent_real: [0.1322] D/latent_fake: [0.1518] D/latent_reg: [0.0821] D/ref_real: [0.0399] D/ref_fake: [0.0441] D/ref_reg: [0.0803] G/latent_adv: [3.3785] G/latent_sty: [0.1435] G/latent_ds: [0.0621] G/latent_cyc: [0.1474] G/ref_adv: [3.5685] G/ref_sty: [0.3982] G/ref_ds: [0.3530] G/ref_cyc: [0.1352] G/lambda_ds: [0.0526]
# Elapsed time [1 day, 10:34:32], Iteration [74460/100000], D/latent_real: [0.0847] D/latent_fake: [0.6279] D/latent_reg: [0.0563] D/ref_real: [0.4815] D/ref_fake: [0.0563] D/ref_reg: [0.0501] G/latent_adv: [2.5788] G/latent_sty: [0.1669] G/latent_ds: [0.0643] G/latent_cyc: [0.1560] G/ref_adv: [2.7066] G/ref_sty: [0.5468] G/ref_ds: [0.3984] G/ref_cyc: [0.1667] G/lambda_ds: [0.0525]
# Elapsed time [1 day, 10:35:23], Iteration [74480/100000], D/latent_real: [0.1140] D/latent_fake: [0.4041] D/latent_reg: [0.0913] D/ref_real: [0.4799] D/ref_fake: [0.0521] D/ref_reg: [0.1020] G/latent_adv: [2.6768] G/latent_sty: [0.1354] G/latent_ds: [0.0661] G/latent_cyc: [0.1458] G/ref_adv: [2.5331] G/ref_sty: [0.4805] G/ref_ds: [0.2758] G/ref_cyc: [0.1249] G/lambda_ds: [0.0525]
# Elapsed time [1 day, 10:36:15], Iteration [74500/100000], D/latent_real: [0.4694] D/latent_fake: [0.2454] D/latent_reg: [0.0874] D/ref_real: [0.0244] D/ref_fake: [0.0901] D/ref_reg: [0.0653] G/latent_adv: [2.5985] G/latent_sty: [0.1596] G/latent_ds: [0.0726] G/latent_cyc: [0.1507] G/ref_adv: [3.6079] G/ref_sty: [0.4904] G/ref_ds: [0.2968] G/ref_cyc: [0.1471] G/lambda_ds: [0.0525]
# Elapsed time [1 day, 10:37:07], Iteration [74520/100000], D/latent_real: [0.2449] D/latent_fake: [0.3371] D/latent_reg: [0.0647] D/ref_real: [0.1607] D/ref_fake: [0.0607] D/ref_reg: [0.0611] G/latent_adv: [2.6010] G/latent_sty: [0.1595] G/latent_ds: [0.0508] G/latent_cyc: [0.1406] G/ref_adv: [3.0748] G/ref_sty: [0.3934] G/ref_ds: [0.3116] G/ref_cyc: [0.1329] G/lambda_ds: [0.0525]
# Elapsed time [1 day, 10:37:59], Iteration [74540/100000], D/latent_real: [0.1820] D/latent_fake: [0.1808] D/latent_reg: [0.1024] D/ref_real: [0.0932] D/ref_fake: [0.0425] D/ref_reg: [0.0892] G/latent_adv: [2.7264] G/latent_sty: [0.1577] G/latent_ds: [0.0598] G/latent_cyc: [0.1392] G/ref_adv: [3.5430] G/ref_sty: [0.5130] G/ref_ds: [0.2544] G/ref_cyc: [0.1442] G/lambda_ds: [0.0525]
# Elapsed time [1 day, 10:38:50], Iteration [74560/100000], D/latent_real: [0.3164] D/latent_fake: [0.4071] D/latent_reg: [0.0671] D/ref_real: [0.3779] D/ref_fake: [0.1116] D/ref_reg: [0.0796] G/latent_adv: [1.2018] G/latent_sty: [0.1606] G/latent_ds: [0.0394] G/latent_cyc: [0.1317] G/ref_adv: [2.1743] G/ref_sty: [0.4590] G/ref_ds: [0.2632] G/ref_cyc: [0.1562] G/lambda_ds: [0.0524]
# Elapsed time [1 day, 10:39:42], Iteration [74580/100000], D/latent_real: [0.1189] D/latent_fake: [0.2415] D/latent_reg: [0.0928] D/ref_real: [0.0776] D/ref_fake: [0.0307] D/ref_reg: [0.0976] G/latent_adv: [3.0201] G/latent_sty: [0.1569] G/latent_ds: [0.0679] G/latent_cyc: [0.1731] G/ref_adv: [3.6160] G/ref_sty: [0.4105] G/ref_ds: [0.3845] G/ref_cyc: [0.1697] G/lambda_ds: [0.0524]
# Elapsed time [1 day, 10:40:34], Iteration [74600/100000], D/latent_real: [0.1673] D/latent_fake: [0.2777] D/latent_reg: [0.1000] D/ref_real: [0.6641] D/ref_fake: [0.0438] D/ref_reg: [0.1141] G/latent_adv: [2.0353] G/latent_sty: [0.1413] G/latent_ds: [0.0640] G/latent_cyc: [0.1617] G/ref_adv: [2.0751] G/ref_sty: [0.3988] G/ref_ds: [0.4997] G/ref_cyc: [0.1516] G/lambda_ds: [0.0524]
# Elapsed time [1 day, 10:41:26], Iteration [74620/100000], D/latent_real: [0.1310] D/latent_fake: [0.2501] D/latent_reg: [0.0858] D/ref_real: [0.1088] D/ref_fake: [0.0440] D/ref_reg: [0.0832] G/latent_adv: [3.3640] G/latent_sty: [0.1823] G/latent_ds: [0.0938] G/latent_cyc: [0.2181] G/ref_adv: [3.3771] G/ref_sty: [0.3767] G/ref_ds: [0.3509] G/ref_cyc: [0.1956] G/lambda_ds: [0.0524]
# Elapsed time [1 day, 10:42:17], Iteration [74640/100000], D/latent_real: [0.1880] D/latent_fake: [0.2841] D/latent_reg: [0.0665] D/ref_real: [0.1211] D/ref_fake: [0.0760] D/ref_reg: [0.0694] G/latent_adv: [2.9858] G/latent_sty: [0.1438] G/latent_ds: [0.0796] G/latent_cyc: [0.1582] G/ref_adv: [3.1652] G/ref_sty: [0.4428] G/ref_ds: [0.3021] G/ref_cyc: [0.1666] G/lambda_ds: [0.0524]
# Elapsed time [1 day, 10:43:09], Iteration [74660/100000], D/latent_real: [0.2236] D/latent_fake: [0.2260] D/latent_reg: [0.0890] D/ref_real: [0.1106] D/ref_fake: [0.2105] D/ref_reg: [0.0741] G/latent_adv: [3.0013] G/latent_sty: [0.1692] G/latent_ds: [0.0849] G/latent_cyc: [0.1666] G/ref_adv: [3.7821] G/ref_sty: [0.2965] G/ref_ds: [0.3257] G/ref_cyc: [0.1716] G/lambda_ds: [0.0523]
# Elapsed time [1 day, 10:44:01], Iteration [74680/100000], D/latent_real: [0.0697] D/latent_fake: [0.2319] D/latent_reg: [0.0700] D/ref_real: [0.3565] D/ref_fake: [0.0573] D/ref_reg: [0.0725] G/latent_adv: [2.5891] G/latent_sty: [0.1136] G/latent_ds: [0.0783] G/latent_cyc: [0.1900] G/ref_adv: [2.6213] G/ref_sty: [0.4194] G/ref_ds: [0.3162] G/ref_cyc: [0.1896] G/lambda_ds: [0.0523]
# Elapsed time [1 day, 10:44:53], Iteration [74700/100000], D/latent_real: [0.1693] D/latent_fake: [0.8718] D/latent_reg: [0.0794] D/ref_real: [0.9302] D/ref_fake: [0.0461] D/ref_reg: [0.0748] G/latent_adv: [1.2738] G/latent_sty: [0.1454] G/latent_ds: [0.0320] G/latent_cyc: [0.1307] G/ref_adv: [1.7650] G/ref_sty: [0.3374] G/ref_ds: [0.3247] G/ref_cyc: [0.1451] G/lambda_ds: [0.0523]
# Elapsed time [1 day, 10:45:44], Iteration [74720/100000], D/latent_real: [0.2096] D/latent_fake: [0.6345] D/latent_reg: [0.0899] D/ref_real: [0.7831] D/ref_fake: [0.0374] D/ref_reg: [0.0918] G/latent_adv: [1.6141] G/latent_sty: [0.1847] G/latent_ds: [0.0480] G/latent_cyc: [0.1182] G/ref_adv: [2.3359] G/ref_sty: [0.4240] G/ref_ds: [0.3622] G/ref_cyc: [0.1400] G/lambda_ds: [0.0523]
# Elapsed time [1 day, 10:46:36], Iteration [74740/100000], D/latent_real: [0.1532] D/latent_fake: [0.5515] D/latent_reg: [0.0541] D/ref_real: [0.2195] D/ref_fake: [0.0912] D/ref_reg: [0.0566] G/latent_adv: [2.4465] G/latent_sty: [0.1284] G/latent_ds: [0.0802] G/latent_cyc: [0.1472] G/ref_adv: [2.6574] G/ref_sty: [0.5097] G/ref_ds: [0.3320] G/ref_cyc: [0.1894] G/lambda_ds: [0.0523]
# Elapsed time [1 day, 10:47:28], Iteration [74760/100000], D/latent_real: [0.1173] D/latent_fake: [0.4736] D/latent_reg: [0.0815] D/ref_real: [0.7128] D/ref_fake: [0.0616] D/ref_reg: [0.0905] G/latent_adv: [1.6960] G/latent_sty: [0.1481] G/latent_ds: [0.0517] G/latent_cyc: [0.1129] G/ref_adv: [2.1388] G/ref_sty: [0.4484] G/ref_ds: [0.2129] G/ref_cyc: [0.1279] G/lambda_ds: [0.0522]
# Elapsed time [1 day, 10:48:20], Iteration [74780/100000], D/latent_real: [0.1891] D/latent_fake: [0.1443] D/latent_reg: [0.0683] D/ref_real: [0.0285] D/ref_fake: [0.0840] D/ref_reg: [0.0611] G/latent_adv: [3.1477] G/latent_sty: [0.1608] G/latent_ds: [0.0776] G/latent_cyc: [0.1547] G/ref_adv: [3.4458] G/ref_sty: [0.4381] G/ref_ds: [0.3601] G/ref_cyc: [0.1441] G/lambda_ds: [0.0522]
# Elapsed time [1 day, 10:49:12], Iteration [74800/100000], D/latent_real: [0.1477] D/latent_fake: [0.1997] D/latent_reg: [0.0798] D/ref_real: [0.1264] D/ref_fake: [0.0407] D/ref_reg: [0.0855] G/latent_adv: [2.8923] G/latent_sty: [0.1438] G/latent_ds: [0.0468] G/latent_cyc: [0.1577] G/ref_adv: [3.2493] G/ref_sty: [0.4171] G/ref_ds: [0.3111] G/ref_cyc: [0.1603] G/lambda_ds: [0.0522]
# Elapsed time [1 day, 10:50:03], Iteration [74820/100000], D/latent_real: [0.0794] D/latent_fake: [0.7173] D/latent_reg: [0.0611] D/ref_real: [0.6924] D/ref_fake: [0.0293] D/ref_reg: [0.0718] G/latent_adv: [1.9570] G/latent_sty: [0.1606] G/latent_ds: [0.0609] G/latent_cyc: [0.1456] G/ref_adv: [2.4909] G/ref_sty: [0.4689] G/ref_ds: [0.3026] G/ref_cyc: [0.1578] G/lambda_ds: [0.0522]
# Elapsed time [1 day, 10:50:55], Iteration [74840/100000], D/latent_real: [0.1754] D/latent_fake: [0.4750] D/latent_reg: [0.0559] D/ref_real: [0.1702] D/ref_fake: [0.1763] D/ref_reg: [0.0571] G/latent_adv: [2.6659] G/latent_sty: [0.1627] G/latent_ds: [0.0705] G/latent_cyc: [0.1569] G/ref_adv: [3.0067] G/ref_sty: [0.4292] G/ref_ds: [0.3384] G/ref_cyc: [0.1726] G/lambda_ds: [0.0522]
# Elapsed time [1 day, 10:51:47], Iteration [74860/100000], D/latent_real: [0.1589] D/latent_fake: [0.4232] D/latent_reg: [0.0648] D/ref_real: [0.2108] D/ref_fake: [0.0891] D/ref_reg: [0.0623] G/latent_adv: [2.5585] G/latent_sty: [0.1655] G/latent_ds: [0.0572] G/latent_cyc: [0.1228] G/ref_adv: [2.8039] G/ref_sty: [0.3780] G/ref_ds: [0.3139] G/ref_cyc: [0.1351] G/lambda_ds: [0.0521]
# Elapsed time [1 day, 10:52:39], Iteration [74880/100000], D/latent_real: [0.1404] D/latent_fake: [0.4746] D/latent_reg: [0.0792] D/ref_real: [0.6127] D/ref_fake: [0.0318] D/ref_reg: [0.0953] G/latent_adv: [2.3862] G/latent_sty: [0.1668] G/latent_ds: [0.0986] G/latent_cyc: [0.1882] G/ref_adv: [2.3042] G/ref_sty: [0.4886] G/ref_ds: [0.4161] G/ref_cyc: [0.1655] G/lambda_ds: [0.0521]
# Elapsed time [1 day, 10:53:31], Iteration [74900/100000], D/latent_real: [0.2418] D/latent_fake: [0.2591] D/latent_reg: [0.0582] D/ref_real: [0.0591] D/ref_fake: [0.0887] D/ref_reg: [0.0608] G/latent_adv: [2.8603] G/latent_sty: [0.1410] G/latent_ds: [0.0742] G/latent_cyc: [0.1894] G/ref_adv: [3.5199] G/ref_sty: [0.5227] G/ref_ds: [0.3139] G/ref_cyc: [0.1922] G/lambda_ds: [0.0521]
# Elapsed time [1 day, 10:54:22], Iteration [74920/100000], D/latent_real: [0.0793] D/latent_fake: [0.2792] D/latent_reg: [0.0906] D/ref_real: [0.2601] D/ref_fake: [0.1204] D/ref_reg: [0.0984] G/latent_adv: [2.8411] G/latent_sty: [0.1669] G/latent_ds: [0.1060] G/latent_cyc: [0.1534] G/ref_adv: [3.6959] G/ref_sty: [0.3801] G/ref_ds: [0.4871] G/ref_cyc: [0.1764] G/lambda_ds: [0.0521]
# Elapsed time [1 day, 10:55:14], Iteration [74940/100000], D/latent_real: [0.1500] D/latent_fake: [0.8647] D/latent_reg: [0.0689] D/ref_real: [1.5262] D/ref_fake: [0.0155] D/ref_reg: [0.0881] G/latent_adv: [1.3041] G/latent_sty: [0.1419] G/latent_ds: [0.0471] G/latent_cyc: [0.1334] G/ref_adv: [1.6727] G/ref_sty: [0.4001] G/ref_ds: [0.2960] G/ref_cyc: [0.1462] G/lambda_ds: [0.0521]
# Elapsed time [1 day, 10:56:06], Iteration [74960/100000], D/latent_real: [0.1468] D/latent_fake: [0.1779] D/latent_reg: [0.1188] D/ref_real: [0.0889] D/ref_fake: [0.0638] D/ref_reg: [0.1054] G/latent_adv: [3.1967] G/latent_sty: [0.1647] G/latent_ds: [0.0602] G/latent_cyc: [0.1747] G/ref_adv: [4.0480] G/ref_sty: [0.3992] G/ref_ds: [0.3898] G/ref_cyc: [0.1796] G/lambda_ds: [0.0520]
# Elapsed time [1 day, 10:56:58], Iteration [74980/100000], D/latent_real: [0.1203] D/latent_fake: [0.2464] D/latent_reg: [0.0785] D/ref_real: [0.1296] D/ref_fake: [0.2152] D/ref_reg: [0.0950] G/latent_adv: [2.8994] G/latent_sty: [0.1569] G/latent_ds: [0.1028] G/latent_cyc: [0.1703] G/ref_adv: [3.7605] G/ref_sty: [0.3330] G/ref_ds: [0.3041] G/ref_cyc: [0.1986] G/lambda_ds: [0.0520]
# Elapsed time [1 day, 10:57:50], Iteration [75000/100000], D/latent_real: [0.4368] D/latent_fake: [0.0771] D/latent_reg: [0.0880] D/ref_real: [0.0143] D/ref_fake: [0.2640] D/ref_reg: [0.0698] G/latent_adv: [3.3945] G/latent_sty: [0.1420] G/latent_ds: [0.0945] G/latent_cyc: [0.1595] G/ref_adv: [5.0454] G/ref_sty: [0.4572] G/ref_ds: [0.3975] G/ref_cyc: [0.1735] G/lambda_ds: [0.0520]
# Saving checkpoint into expr/checkpoints/nets.ckpt...
# Saving checkpoint into expr/checkpoints/nets_ema.ckpt...
# Saving checkpoint into expr/checkpoints/optims.ckpt...
# Elapsed time [1 day, 10:59:13], Iteration [75020/100000], D/latent_real: [0.1499] D/latent_fake: [0.2865] D/latent_reg: [0.1126] D/ref_real: [0.2856] D/ref_fake: [0.0641] D/ref_reg: [0.0988] G/latent_adv: [3.2900] G/latent_sty: [0.1483] G/latent_ds: [0.0526] G/latent_cyc: [0.1288] G/ref_adv: [3.0836] G/ref_sty: [0.3726] G/ref_ds: [0.2878] G/ref_cyc: [0.1377] G/lambda_ds: [0.0520]
# Elapsed time [1 day, 11:00:05], Iteration [75040/100000], D/latent_real: [0.1932] D/latent_fake: [0.2690] D/latent_reg: [0.0694] D/ref_real: [0.2447] D/ref_fake: [0.0438] D/ref_reg: [0.0768] G/latent_adv: [2.3676] G/latent_sty: [0.1513] G/latent_ds: [0.0496] G/latent_cyc: [0.1556] G/ref_adv: [2.2738] G/ref_sty: [0.4760] G/ref_ds: [0.3455] G/ref_cyc: [0.1773] G/lambda_ds: [0.0520]
# Elapsed time [1 day, 11:00:57], Iteration [75060/100000], D/latent_real: [0.1565] D/latent_fake: [0.2454] D/latent_reg: [0.0660] D/ref_real: [0.0250] D/ref_fake: [0.1461] D/ref_reg: [0.0686] G/latent_adv: [3.6981] G/latent_sty: [0.1626] G/latent_ds: [0.1139] G/latent_cyc: [0.1614] G/ref_adv: [3.7813] G/ref_sty: [0.3514] G/ref_ds: [0.2178] G/ref_cyc: [0.1538] G/lambda_ds: [0.0519]
# Elapsed time [1 day, 11:01:49], Iteration [75080/100000], D/latent_real: [0.2971] D/latent_fake: [0.1633] D/latent_reg: [0.0867] D/ref_real: [0.0437] D/ref_fake: [0.2084] D/ref_reg: [0.0763] G/latent_adv: [3.1075] G/latent_sty: [0.1664] G/latent_ds: [0.0847] G/latent_cyc: [0.1656] G/ref_adv: [3.9873] G/ref_sty: [0.2992] G/ref_ds: [0.3688] G/ref_cyc: [0.1867] G/lambda_ds: [0.0519]
# Elapsed time [1 day, 11:02:41], Iteration [75100/100000], D/latent_real: [0.1156] D/latent_fake: [0.0881] D/latent_reg: [0.0756] D/ref_real: [0.0274] D/ref_fake: [0.0917] D/ref_reg: [0.0746] G/latent_adv: [3.4535] G/latent_sty: [0.1543] G/latent_ds: [0.0614] G/latent_cyc: [0.1572] G/ref_adv: [4.1581] G/ref_sty: [0.3675] G/ref_ds: [0.2660] G/ref_cyc: [0.1802] G/lambda_ds: [0.0519]
# Elapsed time [1 day, 11:03:33], Iteration [75120/100000], D/latent_real: [0.2642] D/latent_fake: [0.6819] D/latent_reg: [0.0608] D/ref_real: [0.4119] D/ref_fake: [0.1113] D/ref_reg: [0.0599] G/latent_adv: [3.2228] G/latent_sty: [0.1432] G/latent_ds: [0.0813] G/latent_cyc: [0.1710] G/ref_adv: [2.6228] G/ref_sty: [0.4139] G/ref_ds: [0.3790] G/ref_cyc: [0.1853] G/lambda_ds: [0.0519]
# Elapsed time [1 day, 11:04:24], Iteration [75140/100000], D/latent_real: [0.1404] D/latent_fake: [0.2629] D/latent_reg: [0.0781] D/ref_real: [0.1200] D/ref_fake: [0.0391] D/ref_reg: [0.0782] G/latent_adv: [3.1675] G/latent_sty: [0.1427] G/latent_ds: [0.0525] G/latent_cyc: [0.1411] G/ref_adv: [2.9977] G/ref_sty: [0.3870] G/ref_ds: [0.1935] G/ref_cyc: [0.1590] G/lambda_ds: [0.0519]
# Elapsed time [1 day, 11:05:16], Iteration [75160/100000], D/latent_real: [0.0932] D/latent_fake: [0.3437] D/latent_reg: [0.0516] D/ref_real: [0.1663] D/ref_fake: [0.0400] D/ref_reg: [0.0628] G/latent_adv: [3.1469] G/latent_sty: [0.1690] G/latent_ds: [0.0711] G/latent_cyc: [0.1448] G/ref_adv: [3.2130] G/ref_sty: [0.4616] G/ref_ds: [0.2594] G/ref_cyc: [0.1669] G/lambda_ds: [0.0518]
# Elapsed time [1 day, 11:06:08], Iteration [75180/100000], D/latent_real: [0.2229] D/latent_fake: [0.1562] D/latent_reg: [0.0531] D/ref_real: [0.0338] D/ref_fake: [0.1394] D/ref_reg: [0.0533] G/latent_adv: [3.2117] G/latent_sty: [0.1623] G/latent_ds: [0.1297] G/latent_cyc: [0.1860] G/ref_adv: [3.5434] G/ref_sty: [0.3119] G/ref_ds: [0.3088] G/ref_cyc: [0.1979] G/lambda_ds: [0.0518]
# Elapsed time [1 day, 11:07:00], Iteration [75200/100000], D/latent_real: [0.2449] D/latent_fake: [0.1594] D/latent_reg: [0.0695] D/ref_real: [0.0549] D/ref_fake: [0.1142] D/ref_reg: [0.0666] G/latent_adv: [3.1437] G/latent_sty: [0.1501] G/latent_ds: [0.0908] G/latent_cyc: [0.1493] G/ref_adv: [3.2479] G/ref_sty: [0.4553] G/ref_ds: [0.3497] G/ref_cyc: [0.1333] G/lambda_ds: [0.0518]
# Elapsed time [1 day, 11:07:51], Iteration [75220/100000], D/latent_real: [0.2852] D/latent_fake: [0.1249] D/latent_reg: [0.0792] D/ref_real: [0.0351] D/ref_fake: [0.1187] D/ref_reg: [0.0656] G/latent_adv: [2.9651] G/latent_sty: [0.1382] G/latent_ds: [0.0616] G/latent_cyc: [0.1329] G/ref_adv: [3.8011] G/ref_sty: [0.3599] G/ref_ds: [0.3247] G/ref_cyc: [0.1519] G/lambda_ds: [0.0518]
# Elapsed time [1 day, 11:08:43], Iteration [75240/100000], D/latent_real: [0.0588] D/latent_fake: [0.6765] D/latent_reg: [0.0825] D/ref_real: [1.4683] D/ref_fake: [0.0217] D/ref_reg: [0.0820] G/latent_adv: [1.5480] G/latent_sty: [0.1335] G/latent_ds: [0.1024] G/latent_cyc: [0.1746] G/ref_adv: [2.1851] G/ref_sty: [0.3768] G/ref_ds: [0.3594] G/ref_cyc: [0.1714] G/lambda_ds: [0.0518]
# Elapsed time [1 day, 11:09:35], Iteration [75260/100000], D/latent_real: [0.0787] D/latent_fake: [0.3400] D/latent_reg: [0.0745] D/ref_real: [0.2774] D/ref_fake: [0.1142] D/ref_reg: [0.0897] G/latent_adv: [2.8840] G/latent_sty: [0.1636] G/latent_ds: [0.0529] G/latent_cyc: [0.1351] G/ref_adv: [2.9608] G/ref_sty: [0.3577] G/ref_ds: [0.3532] G/ref_cyc: [0.1436] G/lambda_ds: [0.0517]
# Elapsed time [1 day, 11:10:27], Iteration [75280/100000], D/latent_real: [0.1646] D/latent_fake: [0.1753] D/latent_reg: [0.1041] D/ref_real: [0.0590] D/ref_fake: [0.0654] D/ref_reg: [0.0983] G/latent_adv: [2.9816] G/latent_sty: [0.1296] G/latent_ds: [0.0564] G/latent_cyc: [0.1584] G/ref_adv: [3.4008] G/ref_sty: [0.3939] G/ref_ds: [0.2460] G/ref_cyc: [0.1635] G/lambda_ds: [0.0517]
# Elapsed time [1 day, 11:11:18], Iteration [75300/100000], D/latent_real: [0.3218] D/latent_fake: [0.1897] D/latent_reg: [0.1275] D/ref_real: [0.0206] D/ref_fake: [0.1329] D/ref_reg: [0.0926] G/latent_adv: [3.6435] G/latent_sty: [0.1572] G/latent_ds: [0.0918] G/latent_cyc: [0.1708] G/ref_adv: [4.3354] G/ref_sty: [0.3980] G/ref_ds: [0.3609] G/ref_cyc: [0.1609] G/lambda_ds: [0.0517]
# Elapsed time [1 day, 11:12:10], Iteration [75320/100000], D/latent_real: [0.5068] D/latent_fake: [0.1101] D/latent_reg: [0.0736] D/ref_real: [0.0112] D/ref_fake: [0.3797] D/ref_reg: [0.0530] G/latent_adv: [3.5349] G/latent_sty: [0.1880] G/latent_ds: [0.0991] G/latent_cyc: [0.1596] G/ref_adv: [4.1294] G/ref_sty: [0.3486] G/ref_ds: [0.6458] G/ref_cyc: [0.1744] G/lambda_ds: [0.0517]
# Elapsed time [1 day, 11:13:02], Iteration [75340/100000], D/latent_real: [0.1319] D/latent_fake: [0.4229] D/latent_reg: [0.0965] D/ref_real: [0.9780] D/ref_fake: [0.0157] D/ref_reg: [0.1082] G/latent_adv: [1.6402] G/latent_sty: [0.1479] G/latent_ds: [0.0925] G/latent_cyc: [0.1795] G/ref_adv: [2.1517] G/ref_sty: [0.3472] G/ref_ds: [0.3056] G/ref_cyc: [0.2116] G/lambda_ds: [0.0517]
# Elapsed time [1 day, 11:13:54], Iteration [75360/100000], D/latent_real: [0.3893] D/latent_fake: [0.3223] D/latent_reg: [0.0916] D/ref_real: [0.1939] D/ref_fake: [0.0800] D/ref_reg: [0.0699] G/latent_adv: [2.2270] G/latent_sty: [0.1366] G/latent_ds: [0.0387] G/latent_cyc: [0.1346] G/ref_adv: [2.8037] G/ref_sty: [0.3964] G/ref_ds: [0.2825] G/ref_cyc: [0.1408] G/lambda_ds: [0.0516]
# Elapsed time [1 day, 11:14:46], Iteration [75380/100000], D/latent_real: [0.2103] D/latent_fake: [0.6231] D/latent_reg: [0.0988] D/ref_real: [0.5181] D/ref_fake: [0.0660] D/ref_reg: [0.0561] G/latent_adv: [2.2011] G/latent_sty: [0.1606] G/latent_ds: [0.0921] G/latent_cyc: [0.1534] G/ref_adv: [2.1751] G/ref_sty: [0.3809] G/ref_ds: [0.3557] G/ref_cyc: [0.1635] G/lambda_ds: [0.0516]
# Elapsed time [1 day, 11:15:37], Iteration [75400/100000], D/latent_real: [0.0776] D/latent_fake: [0.3174] D/latent_reg: [0.0712] D/ref_real: [0.4089] D/ref_fake: [0.0708] D/ref_reg: [0.0782] G/latent_adv: [2.5414] G/latent_sty: [0.1470] G/latent_ds: [0.0923] G/latent_cyc: [0.1649] G/ref_adv: [2.8066] G/ref_sty: [0.3406] G/ref_ds: [0.3652] G/ref_cyc: [0.1965] G/lambda_ds: [0.0516]
# Elapsed time [1 day, 11:16:29], Iteration [75420/100000], D/latent_real: [0.6197] D/latent_fake: [0.1445] D/latent_reg: [0.0975] D/ref_real: [0.0166] D/ref_fake: [0.1576] D/ref_reg: [0.0612] G/latent_adv: [2.8509] G/latent_sty: [0.1516] G/latent_ds: [0.0718] G/latent_cyc: [0.1463] G/ref_adv: [3.4191] G/ref_sty: [0.3800] G/ref_ds: [0.3596] G/ref_cyc: [0.1494] G/lambda_ds: [0.0516]
# Elapsed time [1 day, 11:17:21], Iteration [75440/100000], D/latent_real: [0.1690] D/latent_fake: [0.0822] D/latent_reg: [0.0851] D/ref_real: [0.0175] D/ref_fake: [0.2944] D/ref_reg: [0.0764] G/latent_adv: [4.1024] G/latent_sty: [0.1760] G/latent_ds: [0.0646] G/latent_cyc: [0.1760] G/ref_adv: [5.2686] G/ref_sty: [0.4115] G/ref_ds: [0.3671] G/ref_cyc: [0.1523] G/lambda_ds: [0.0516]
# Elapsed time [1 day, 11:18:13], Iteration [75460/100000], D/latent_real: [0.2122] D/latent_fake: [0.3386] D/latent_reg: [0.0898] D/ref_real: [0.2264] D/ref_fake: [0.0593] D/ref_reg: [0.0945] G/latent_adv: [2.2454] G/latent_sty: [0.1581] G/latent_ds: [0.0717] G/latent_cyc: [0.1658] G/ref_adv: [2.9808] G/ref_sty: [0.4449] G/ref_ds: [0.3573] G/ref_cyc: [0.1685] G/lambda_ds: [0.0515]
# Elapsed time [1 day, 11:19:04], Iteration [75480/100000], D/latent_real: [0.3926] D/latent_fake: [0.2201] D/latent_reg: [0.0889] D/ref_real: [0.1265] D/ref_fake: [0.1027] D/ref_reg: [0.0656] G/latent_adv: [2.6593] G/latent_sty: [0.1744] G/latent_ds: [0.0758] G/latent_cyc: [0.1426] G/ref_adv: [3.0251] G/ref_sty: [0.3682] G/ref_ds: [0.4887] G/ref_cyc: [0.1583] G/lambda_ds: [0.0515]
# Elapsed time [1 day, 11:19:56], Iteration [75500/100000], D/latent_real: [0.1329] D/latent_fake: [0.4394] D/latent_reg: [0.0614] D/ref_real: [0.3973] D/ref_fake: [0.0573] D/ref_reg: [0.0703] G/latent_adv: [2.3904] G/latent_sty: [0.1554] G/latent_ds: [0.0478] G/latent_cyc: [0.1367] G/ref_adv: [2.8494] G/ref_sty: [0.3577] G/ref_ds: [0.3232] G/ref_cyc: [0.1566] G/lambda_ds: [0.0515]
# Elapsed time [1 day, 11:20:48], Iteration [75520/100000], D/latent_real: [0.1319] D/latent_fake: [0.5780] D/latent_reg: [0.0715] D/ref_real: [0.7269] D/ref_fake: [0.0432] D/ref_reg: [0.0661] G/latent_adv: [1.8898] G/latent_sty: [0.1545] G/latent_ds: [0.0854] G/latent_cyc: [0.1818] G/ref_adv: [2.0469] G/ref_sty: [0.3457] G/ref_ds: [0.3287] G/ref_cyc: [0.1917] G/lambda_ds: [0.0515]
# Elapsed time [1 day, 11:21:40], Iteration [75540/100000], D/latent_real: [0.2165] D/latent_fake: [0.1292] D/latent_reg: [0.0756] D/ref_real: [0.0136] D/ref_fake: [0.0374] D/ref_reg: [0.0645] G/latent_adv: [3.3020] G/latent_sty: [0.1442] G/latent_ds: [0.0802] G/latent_cyc: [0.1425] G/ref_adv: [3.9070] G/ref_sty: [0.3384] G/ref_ds: [0.3523] G/ref_cyc: [0.1392] G/lambda_ds: [0.0515]
# Elapsed time [1 day, 11:22:32], Iteration [75560/100000], D/latent_real: [0.0800] D/latent_fake: [0.3311] D/latent_reg: [0.0748] D/ref_real: [0.3021] D/ref_fake: [0.1055] D/ref_reg: [0.0601] G/latent_adv: [3.0736] G/latent_sty: [0.1257] G/latent_ds: [0.0566] G/latent_cyc: [0.1576] G/ref_adv: [2.7888] G/ref_sty: [0.3050] G/ref_ds: [0.3369] G/ref_cyc: [0.1537] G/lambda_ds: [0.0514]
# Elapsed time [1 day, 11:23:23], Iteration [75580/100000], D/latent_real: [0.2277] D/latent_fake: [0.4270] D/latent_reg: [0.0674] D/ref_real: [0.0565] D/ref_fake: [0.0953] D/ref_reg: [0.0595] G/latent_adv: [3.2268] G/latent_sty: [0.1481] G/latent_ds: [0.0997] G/latent_cyc: [0.1462] G/ref_adv: [3.2878] G/ref_sty: [0.3655] G/ref_ds: [0.3384] G/ref_cyc: [0.1415] G/lambda_ds: [0.0514]
# Elapsed time [1 day, 11:24:15], Iteration [75600/100000], D/latent_real: [0.1108] D/latent_fake: [0.2937] D/latent_reg: [0.0760] D/ref_real: [0.2150] D/ref_fake: [0.0538] D/ref_reg: [0.0790] G/latent_adv: [2.6184] G/latent_sty: [0.1513] G/latent_ds: [0.0677] G/latent_cyc: [0.1511] G/ref_adv: [3.1145] G/ref_sty: [0.4286] G/ref_ds: [0.3679] G/ref_cyc: [0.1567] G/lambda_ds: [0.0514]
# Elapsed time [1 day, 11:25:07], Iteration [75620/100000], D/latent_real: [0.0724] D/latent_fake: [0.6530] D/latent_reg: [0.0812] D/ref_real: [1.1238] D/ref_fake: [0.0585] D/ref_reg: [0.0760] G/latent_adv: [2.0572] G/latent_sty: [0.1548] G/latent_ds: [0.0507] G/latent_cyc: [0.1455] G/ref_adv: [2.3879] G/ref_sty: [0.4419] G/ref_ds: [0.3051] G/ref_cyc: [0.1490] G/lambda_ds: [0.0514]
# Elapsed time [1 day, 11:25:59], Iteration [75640/100000], D/latent_real: [0.1004] D/latent_fake: [0.2123] D/latent_reg: [0.0708] D/ref_real: [0.1245] D/ref_fake: [0.0581] D/ref_reg: [0.0781] G/latent_adv: [2.8893] G/latent_sty: [0.1592] G/latent_ds: [0.0535] G/latent_cyc: [0.1583] G/ref_adv: [3.2485] G/ref_sty: [0.4073] G/ref_ds: [0.3116] G/ref_cyc: [0.1603] G/lambda_ds: [0.0514]
# Elapsed time [1 day, 11:26:50], Iteration [75660/100000], D/latent_real: [0.0606] D/latent_fake: [0.2048] D/latent_reg: [0.0946] D/ref_real: [0.1670] D/ref_fake: [0.0936] D/ref_reg: [0.0999] G/latent_adv: [3.1116] G/latent_sty: [0.1617] G/latent_ds: [0.0658] G/latent_cyc: [0.1637] G/ref_adv: [3.1787] G/ref_sty: [0.3651] G/ref_ds: [0.2742] G/ref_cyc: [0.1764] G/lambda_ds: [0.0513]
# Elapsed time [1 day, 11:27:42], Iteration [75680/100000], D/latent_real: [0.0859] D/latent_fake: [0.3948] D/latent_reg: [0.0781] D/ref_real: [0.4626] D/ref_fake: [0.0446] D/ref_reg: [0.0821] G/latent_adv: [2.1186] G/latent_sty: [0.1480] G/latent_ds: [0.0978] G/latent_cyc: [0.1587] G/ref_adv: [2.5296] G/ref_sty: [0.3473] G/ref_ds: [0.2538] G/ref_cyc: [0.1429] G/lambda_ds: [0.0513]
# Elapsed time [1 day, 11:28:34], Iteration [75700/100000], D/latent_real: [0.0640] D/latent_fake: [0.0570] D/latent_reg: [0.0627] D/ref_real: [0.0295] D/ref_fake: [0.0415] D/ref_reg: [0.0627] G/latent_adv: [3.6366] G/latent_sty: [0.1693] G/latent_ds: [0.0913] G/latent_cyc: [0.1953] G/ref_adv: [3.7460] G/ref_sty: [0.4364] G/ref_ds: [0.3248] G/ref_cyc: [0.1648] G/lambda_ds: [0.0513]
# Elapsed time [1 day, 11:29:26], Iteration [75720/100000], D/latent_real: [0.1504] D/latent_fake: [0.3815] D/latent_reg: [0.0888] D/ref_real: [0.3160] D/ref_fake: [0.0533] D/ref_reg: [0.0908] G/latent_adv: [2.1929] G/latent_sty: [0.1442] G/latent_ds: [0.0439] G/latent_cyc: [0.1298] G/ref_adv: [2.3523] G/ref_sty: [0.4732] G/ref_ds: [0.3538] G/ref_cyc: [0.1517] G/lambda_ds: [0.0513]
# Elapsed time [1 day, 11:30:17], Iteration [75740/100000], D/latent_real: [0.1164] D/latent_fake: [0.1176] D/latent_reg: [0.0914] D/ref_real: [0.0307] D/ref_fake: [0.0818] D/ref_reg: [0.0905] G/latent_adv: [3.1503] G/latent_sty: [0.1779] G/latent_ds: [0.0807] G/latent_cyc: [0.1588] G/ref_adv: [4.0129] G/ref_sty: [0.3428] G/ref_ds: [0.3671] G/ref_cyc: [0.1641] G/lambda_ds: [0.0513]
# Elapsed time [1 day, 11:31:10], Iteration [75760/100000], D/latent_real: [0.3947] D/latent_fake: [0.2954] D/latent_reg: [0.0906] D/ref_real: [0.1450] D/ref_fake: [0.1506] D/ref_reg: [0.0729] G/latent_adv: [2.8671] G/latent_sty: [0.1513] G/latent_ds: [0.0732] G/latent_cyc: [0.1565] G/ref_adv: [3.4957] G/ref_sty: [0.3641] G/ref_ds: [0.3745] G/ref_cyc: [0.1541] G/lambda_ds: [0.0512]
# Elapsed time [1 day, 11:32:02], Iteration [75780/100000], D/latent_real: [0.2723] D/latent_fake: [0.1314] D/latent_reg: [0.0770] D/ref_real: [0.0208] D/ref_fake: [0.1175] D/ref_reg: [0.0505] G/latent_adv: [3.3325] G/latent_sty: [0.1432] G/latent_ds: [0.1185] G/latent_cyc: [0.1654] G/ref_adv: [3.7072] G/ref_sty: [0.2760] G/ref_ds: [0.3708] G/ref_cyc: [0.1928] G/lambda_ds: [0.0512]
# Elapsed time [1 day, 11:32:53], Iteration [75800/100000], D/latent_real: [0.1626] D/latent_fake: [0.1597] D/latent_reg: [0.0503] D/ref_real: [0.0607] D/ref_fake: [0.1396] D/ref_reg: [0.0502] G/latent_adv: [2.9097] G/latent_sty: [0.1484] G/latent_ds: [0.0675] G/latent_cyc: [0.1465] G/ref_adv: [2.8549] G/ref_sty: [0.3509] G/ref_ds: [0.3066] G/ref_cyc: [0.1518] G/lambda_ds: [0.0512]
# Elapsed time [1 day, 11:33:45], Iteration [75820/100000], D/latent_real: [0.1587] D/latent_fake: [0.2638] D/latent_reg: [0.0915] D/ref_real: [0.1718] D/ref_fake: [0.0941] D/ref_reg: [0.0880] G/latent_adv: [2.9112] G/latent_sty: [0.1537] G/latent_ds: [0.0828] G/latent_cyc: [0.1872] G/ref_adv: [2.9937] G/ref_sty: [0.4194] G/ref_ds: [0.3447] G/ref_cyc: [0.1701] G/lambda_ds: [0.0512]
# Elapsed time [1 day, 11:34:37], Iteration [75840/100000], D/latent_real: [0.3301] D/latent_fake: [0.1169] D/latent_reg: [0.1083] D/ref_real: [0.0202] D/ref_fake: [0.1409] D/ref_reg: [0.0726] G/latent_adv: [2.9810] G/latent_sty: [0.1444] G/latent_ds: [0.0518] G/latent_cyc: [0.1523] G/ref_adv: [3.9071] G/ref_sty: [0.3574] G/ref_ds: [0.4535] G/ref_cyc: [0.1493] G/lambda_ds: [0.0512]
# Elapsed time [1 day, 11:35:29], Iteration [75860/100000], D/latent_real: [0.6366] D/latent_fake: [0.2215] D/latent_reg: [0.0897] D/ref_real: [0.1199] D/ref_fake: [0.1077] D/ref_reg: [0.0714] G/latent_adv: [2.1286] G/latent_sty: [0.1607] G/latent_ds: [0.0992] G/latent_cyc: [0.1568] G/ref_adv: [2.9576] G/ref_sty: [0.4199] G/ref_ds: [0.3465] G/ref_cyc: [0.1712] G/lambda_ds: [0.0511]
# Elapsed time [1 day, 11:36:21], Iteration [75880/100000], D/latent_real: [0.1743] D/latent_fake: [0.2908] D/latent_reg: [0.0930] D/ref_real: [0.1035] D/ref_fake: [0.1454] D/ref_reg: [0.1017] G/latent_adv: [3.8292] G/latent_sty: [0.1468] G/latent_ds: [0.0377] G/latent_cyc: [0.1788] G/ref_adv: [3.8695] G/ref_sty: [0.4764] G/ref_ds: [0.3142] G/ref_cyc: [0.1719] G/lambda_ds: [0.0511]
# Elapsed time [1 day, 11:37:12], Iteration [75900/100000], D/latent_real: [0.1433] D/latent_fake: [0.3895] D/latent_reg: [0.0736] D/ref_real: [0.2089] D/ref_fake: [0.0304] D/ref_reg: [0.0758] G/latent_adv: [3.4403] G/latent_sty: [0.1613] G/latent_ds: [0.0781] G/latent_cyc: [0.1757] G/ref_adv: [3.4253] G/ref_sty: [0.4346] G/ref_ds: [0.4108] G/ref_cyc: [0.1656] G/lambda_ds: [0.0511]
# Elapsed time [1 day, 11:38:04], Iteration [75920/100000], D/latent_real: [0.3549] D/latent_fake: [0.2053] D/latent_reg: [0.0687] D/ref_real: [0.0207] D/ref_fake: [0.1683] D/ref_reg: [0.0556] G/latent_adv: [3.1678] G/latent_sty: [0.1635] G/latent_ds: [0.0849] G/latent_cyc: [0.1839] G/ref_adv: [3.9736] G/ref_sty: [0.3016] G/ref_ds: [0.2866] G/ref_cyc: [0.1691] G/lambda_ds: [0.0511]
# Elapsed time [1 day, 11:38:56], Iteration [75940/100000], D/latent_real: [0.1714] D/latent_fake: [0.0628] D/latent_reg: [0.0955] D/ref_real: [0.0225] D/ref_fake: [0.0768] D/ref_reg: [0.0828] G/latent_adv: [3.9790] G/latent_sty: [0.1532] G/latent_ds: [0.0930] G/latent_cyc: [0.1518] G/ref_adv: [4.3119] G/ref_sty: [0.4621] G/ref_ds: [0.3849] G/ref_cyc: [0.1626] G/lambda_ds: [0.0511]
# Elapsed time [1 day, 11:39:48], Iteration [75960/100000], D/latent_real: [0.1608] D/latent_fake: [0.1560] D/latent_reg: [0.0894] D/ref_real: [0.0408] D/ref_fake: [0.0464] D/ref_reg: [0.0781] G/latent_adv: [3.5486] G/latent_sty: [0.1636] G/latent_ds: [0.0848] G/latent_cyc: [0.1631] G/ref_adv: [3.6592] G/ref_sty: [0.3766] G/ref_ds: [0.3542] G/ref_cyc: [0.1785] G/lambda_ds: [0.0510]
# Elapsed time [1 day, 11:40:39], Iteration [75980/100000], D/latent_real: [0.2469] D/latent_fake: [0.1013] D/latent_reg: [0.0719] D/ref_real: [0.0186] D/ref_fake: [0.2472] D/ref_reg: [0.0451] G/latent_adv: [3.8226] G/latent_sty: [0.1606] G/latent_ds: [0.1047] G/latent_cyc: [0.1862] G/ref_adv: [4.9695] G/ref_sty: [0.2917] G/ref_ds: [0.3621] G/ref_cyc: [0.1909] G/lambda_ds: [0.0510]
# Elapsed time [1 day, 11:41:31], Iteration [76000/100000], D/latent_real: [0.1463] D/latent_fake: [0.1172] D/latent_reg: [0.0837] D/ref_real: [0.0373] D/ref_fake: [0.0766] D/ref_reg: [0.0797] G/latent_adv: [3.1228] G/latent_sty: [0.1356] G/latent_ds: [0.0854] G/latent_cyc: [0.1414] G/ref_adv: [3.5324] G/ref_sty: [0.3212] G/ref_ds: [0.3758] G/ref_cyc: [0.1482] G/lambda_ds: [0.0510]
# Saving checkpoint into expr/checkpoints/nets.ckpt...
# Saving checkpoint into expr/checkpoints/nets_ema.ckpt...
# Saving checkpoint into expr/checkpoints/optims.ckpt...
# Elapsed time [1 day, 11:42:54], Iteration [76020/100000], D/latent_real: [0.1879] D/latent_fake: [0.2215] D/latent_reg: [0.0774] D/ref_real: [0.1364] D/ref_fake: [0.0959] D/ref_reg: [0.0746] G/latent_adv: [2.9425] G/latent_sty: [0.1643] G/latent_ds: [0.0749] G/latent_cyc: [0.1708] G/ref_adv: [3.2613] G/ref_sty: [0.3503] G/ref_ds: [0.2536] G/ref_cyc: [0.1524] G/lambda_ds: [0.0510]
# Elapsed time [1 day, 11:43:46], Iteration [76040/100000], D/latent_real: [0.2721] D/latent_fake: [0.2013] D/latent_reg: [0.0692] D/ref_real: [0.0234] D/ref_fake: [0.0600] D/ref_reg: [0.0591] G/latent_adv: [3.5595] G/latent_sty: [0.1616] G/latent_ds: [0.0692] G/latent_cyc: [0.1470] G/ref_adv: [3.3991] G/ref_sty: [0.3799] G/ref_ds: [0.2136] G/ref_cyc: [0.1404] G/lambda_ds: [0.0510]
# Elapsed time [1 day, 11:44:37], Iteration [76060/100000], D/latent_real: [0.2315] D/latent_fake: [0.3203] D/latent_reg: [0.0623] D/ref_real: [0.1303] D/ref_fake: [0.1478] D/ref_reg: [0.0633] G/latent_adv: [3.8556] G/latent_sty: [0.1508] G/latent_ds: [0.0850] G/latent_cyc: [0.1824] G/ref_adv: [3.1620] G/ref_sty: [0.3847] G/ref_ds: [0.3921] G/ref_cyc: [0.1650] G/lambda_ds: [0.0509]
# Elapsed time [1 day, 11:45:29], Iteration [76080/100000], D/latent_real: [0.1676] D/latent_fake: [0.3380] D/latent_reg: [0.0625] D/ref_real: [0.2213] D/ref_fake: [0.2165] D/ref_reg: [0.0651] G/latent_adv: [2.7290] G/latent_sty: [0.1300] G/latent_ds: [0.0713] G/latent_cyc: [0.1455] G/ref_adv: [3.0350] G/ref_sty: [0.3463] G/ref_ds: [0.3289] G/ref_cyc: [0.1481] G/lambda_ds: [0.0509]
# Elapsed time [1 day, 11:46:21], Iteration [76100/100000], D/latent_real: [0.1456] D/latent_fake: [0.2088] D/latent_reg: [0.0864] D/ref_real: [0.1039] D/ref_fake: [0.0946] D/ref_reg: [0.0941] G/latent_adv: [3.0751] G/latent_sty: [0.1670] G/latent_ds: [0.0732] G/latent_cyc: [0.1579] G/ref_adv: [3.5309] G/ref_sty: [0.3598] G/ref_ds: [0.3241] G/ref_cyc: [0.1533] G/lambda_ds: [0.0509]
# Elapsed time [1 day, 11:47:13], Iteration [76120/100000], D/latent_real: [0.2633] D/latent_fake: [0.3199] D/latent_reg: [0.0625] D/ref_real: [0.1905] D/ref_fake: [0.1236] D/ref_reg: [0.0635] G/latent_adv: [2.7764] G/latent_sty: [0.1783] G/latent_ds: [0.0864] G/latent_cyc: [0.1619] G/ref_adv: [3.0767] G/ref_sty: [0.4259] G/ref_ds: [0.3356] G/ref_cyc: [0.1740] G/lambda_ds: [0.0509]
# Elapsed time [1 day, 11:48:04], Iteration [76140/100000], D/latent_real: [0.1379] D/latent_fake: [0.1075] D/latent_reg: [0.0868] D/ref_real: [0.0185] D/ref_fake: [0.0794] D/ref_reg: [0.0785] G/latent_adv: [3.8554] G/latent_sty: [0.1699] G/latent_ds: [0.0741] G/latent_cyc: [0.1640] G/ref_adv: [4.0380] G/ref_sty: [0.4899] G/ref_ds: [0.4278] G/ref_cyc: [0.1657] G/lambda_ds: [0.0509]
# Elapsed time [1 day, 11:48:56], Iteration [76160/100000], D/latent_real: [0.2017] D/latent_fake: [0.4554] D/latent_reg: [0.0612] D/ref_real: [0.5122] D/ref_fake: [0.0538] D/ref_reg: [0.0674] G/latent_adv: [2.0736] G/latent_sty: [0.1675] G/latent_ds: [0.0907] G/latent_cyc: [0.1635] G/ref_adv: [2.6940] G/ref_sty: [0.5799] G/ref_ds: [0.3118] G/ref_cyc: [0.1700] G/lambda_ds: [0.0508]
# Elapsed time [1 day, 11:49:48], Iteration [76180/100000], D/latent_real: [0.3123] D/latent_fake: [0.3429] D/latent_reg: [0.0722] D/ref_real: [0.1576] D/ref_fake: [0.1621] D/ref_reg: [0.0577] G/latent_adv: [2.4334] G/latent_sty: [0.1452] G/latent_ds: [0.1357] G/latent_cyc: [0.1602] G/ref_adv: [3.0637] G/ref_sty: [0.4504] G/ref_ds: [0.4949] G/ref_cyc: [0.1737] G/lambda_ds: [0.0508]
# Elapsed time [1 day, 11:50:40], Iteration [76200/100000], D/latent_real: [0.4134] D/latent_fake: [0.4950] D/latent_reg: [0.0662] D/ref_real: [0.5239] D/ref_fake: [0.1104] D/ref_reg: [0.0795] G/latent_adv: [1.7763] G/latent_sty: [0.1451] G/latent_ds: [0.0486] G/latent_cyc: [0.1550] G/ref_adv: [2.1320] G/ref_sty: [0.3250] G/ref_ds: [0.3687] G/ref_cyc: [0.1683] G/lambda_ds: [0.0508]
# Elapsed time [1 day, 11:51:32], Iteration [76220/100000], D/latent_real: [0.1068] D/latent_fake: [0.2023] D/latent_reg: [0.0703] D/ref_real: [0.1384] D/ref_fake: [0.0882] D/ref_reg: [0.0729] G/latent_adv: [2.7661] G/latent_sty: [0.1470] G/latent_ds: [0.0734] G/latent_cyc: [0.1657] G/ref_adv: [3.1262] G/ref_sty: [0.5032] G/ref_ds: [0.4365] G/ref_cyc: [0.1824] G/lambda_ds: [0.0508]
# Elapsed time [1 day, 11:52:24], Iteration [76240/100000], D/latent_real: [0.1612] D/latent_fake: [0.4290] D/latent_reg: [0.0855] D/ref_real: [0.6107] D/ref_fake: [0.0629] D/ref_reg: [0.0948] G/latent_adv: [2.6289] G/latent_sty: [0.1272] G/latent_ds: [0.0606] G/latent_cyc: [0.1349] G/ref_adv: [2.5587] G/ref_sty: [0.4825] G/ref_ds: [0.2848] G/ref_cyc: [0.1456] G/lambda_ds: [0.0508]
# Elapsed time [1 day, 11:53:16], Iteration [76260/100000], D/latent_real: [0.1601] D/latent_fake: [0.3700] D/latent_reg: [0.0949] D/ref_real: [0.2902] D/ref_fake: [0.0476] D/ref_reg: [0.0884] G/latent_adv: [2.7959] G/latent_sty: [0.1336] G/latent_ds: [0.0855] G/latent_cyc: [0.1519] G/ref_adv: [2.7308] G/ref_sty: [0.4323] G/ref_ds: [0.3775] G/ref_cyc: [0.1456] G/lambda_ds: [0.0507]
# Elapsed time [1 day, 11:54:08], Iteration [76280/100000], D/latent_real: [0.1205] D/latent_fake: [0.2377] D/latent_reg: [0.0578] D/ref_real: [0.0452] D/ref_fake: [0.1160] D/ref_reg: [0.0601] G/latent_adv: [3.1356] G/latent_sty: [0.1391] G/latent_ds: [0.0362] G/latent_cyc: [0.1380] G/ref_adv: [3.2242] G/ref_sty: [0.3336] G/ref_ds: [0.3795] G/ref_cyc: [0.1350] G/lambda_ds: [0.0507]
# Elapsed time [1 day, 11:55:00], Iteration [76300/100000], D/latent_real: [0.4577] D/latent_fake: [0.2054] D/latent_reg: [0.0866] D/ref_real: [0.0501] D/ref_fake: [0.0975] D/ref_reg: [0.0808] G/latent_adv: [3.2032] G/latent_sty: [0.1442] G/latent_ds: [0.0591] G/latent_cyc: [0.1568] G/ref_adv: [3.5614] G/ref_sty: [0.3839] G/ref_ds: [0.3686] G/ref_cyc: [0.1459] G/lambda_ds: [0.0507]
# Elapsed time [1 day, 11:55:52], Iteration [76320/100000], D/latent_real: [0.1091] D/latent_fake: [0.4520] D/latent_reg: [0.0688] D/ref_real: [0.2983] D/ref_fake: [0.0384] D/ref_reg: [0.0729] G/latent_adv: [3.1580] G/latent_sty: [0.1490] G/latent_ds: [0.0345] G/latent_cyc: [0.1494] G/ref_adv: [3.1391] G/ref_sty: [0.3168] G/ref_ds: [0.3796] G/ref_cyc: [0.1487] G/lambda_ds: [0.0507]
# Elapsed time [1 day, 11:56:44], Iteration [76340/100000], D/latent_real: [0.2395] D/latent_fake: [0.1175] D/latent_reg: [0.0833] D/ref_real: [0.0344] D/ref_fake: [0.0763] D/ref_reg: [0.0714] G/latent_adv: [3.0673] G/latent_sty: [0.1313] G/latent_ds: [0.0757] G/latent_cyc: [0.1578] G/ref_adv: [3.3726] G/ref_sty: [0.3012] G/ref_ds: [0.4062] G/ref_cyc: [0.1669] G/lambda_ds: [0.0507]
# Elapsed time [1 day, 11:57:36], Iteration [76360/100000], D/latent_real: [0.1277] D/latent_fake: [0.1479] D/latent_reg: [0.0686] D/ref_real: [0.0438] D/ref_fake: [0.1478] D/ref_reg: [0.0680] G/latent_adv: [3.1177] G/latent_sty: [0.1379] G/latent_ds: [0.0570] G/latent_cyc: [0.1422] G/ref_adv: [3.6896] G/ref_sty: [0.3912] G/ref_ds: [0.3538] G/ref_cyc: [0.1734] G/lambda_ds: [0.0506]
# Elapsed time [1 day, 11:58:28], Iteration [76380/100000], D/latent_real: [0.3989] D/latent_fake: [0.2268] D/latent_reg: [0.1183] D/ref_real: [0.0710] D/ref_fake: [0.2849] D/ref_reg: [0.0987] G/latent_adv: [3.8334] G/latent_sty: [0.1443] G/latent_ds: [0.0562] G/latent_cyc: [0.1521] G/ref_adv: [3.9703] G/ref_sty: [0.3869] G/ref_ds: [0.4569] G/ref_cyc: [0.1627] G/lambda_ds: [0.0506]
# Elapsed time [1 day, 11:59:20], Iteration [76400/100000], D/latent_real: [0.2163] D/latent_fake: [0.2696] D/latent_reg: [0.0864] D/ref_real: [0.1289] D/ref_fake: [0.0606] D/ref_reg: [0.0741] G/latent_adv: [2.8562] G/latent_sty: [0.1544] G/latent_ds: [0.0564] G/latent_cyc: [0.1351] G/ref_adv: [3.1747] G/ref_sty: [0.3135] G/ref_ds: [0.3697] G/ref_cyc: [0.1534] G/lambda_ds: [0.0506]
# Elapsed time [1 day, 12:00:12], Iteration [76420/100000], D/latent_real: [0.4146] D/latent_fake: [0.2695] D/latent_reg: [0.0921] D/ref_real: [0.2206] D/ref_fake: [0.0336] D/ref_reg: [0.0711] G/latent_adv: [2.7739] G/latent_sty: [0.1555] G/latent_ds: [0.0430] G/latent_cyc: [0.1322] G/ref_adv: [3.1608] G/ref_sty: [0.3025] G/ref_ds: [0.3187] G/ref_cyc: [0.1472] G/lambda_ds: [0.0506]
# Elapsed time [1 day, 12:01:04], Iteration [76440/100000], D/latent_real: [0.3212] D/latent_fake: [0.3763] D/latent_reg: [0.0784] D/ref_real: [0.1947] D/ref_fake: [0.0990] D/ref_reg: [0.0658] G/latent_adv: [2.5719] G/latent_sty: [0.1488] G/latent_ds: [0.0740] G/latent_cyc: [0.1356] G/ref_adv: [2.5108] G/ref_sty: [0.3652] G/ref_ds: [0.2447] G/ref_cyc: [0.1490] G/lambda_ds: [0.0506]
# Elapsed time [1 day, 12:01:56], Iteration [76460/100000], D/latent_real: [0.4334] D/latent_fake: [0.2662] D/latent_reg: [0.1015] D/ref_real: [0.1521] D/ref_fake: [0.1185] D/ref_reg: [0.0555] G/latent_adv: [2.9786] G/latent_sty: [0.1552] G/latent_ds: [0.0632] G/latent_cyc: [0.1506] G/ref_adv: [2.9623] G/ref_sty: [0.4208] G/ref_ds: [0.2316] G/ref_cyc: [0.1352] G/lambda_ds: [0.0505]
# Elapsed time [1 day, 12:02:48], Iteration [76480/100000], D/latent_real: [0.3520] D/latent_fake: [0.1934] D/latent_reg: [0.0682] D/ref_real: [0.0199] D/ref_fake: [0.1283] D/ref_reg: [0.0599] G/latent_adv: [3.4939] G/latent_sty: [0.1651] G/latent_ds: [0.0919] G/latent_cyc: [0.1646] G/ref_adv: [3.5193] G/ref_sty: [0.3266] G/ref_ds: [0.3410] G/ref_cyc: [0.1590] G/lambda_ds: [0.0505]
# Elapsed time [1 day, 12:03:40], Iteration [76500/100000], D/latent_real: [0.2734] D/latent_fake: [0.5008] D/latent_reg: [0.0636] D/ref_real: [0.3536] D/ref_fake: [0.1552] D/ref_reg: [0.0598] G/latent_adv: [2.6386] G/latent_sty: [0.1853] G/latent_ds: [0.1132] G/latent_cyc: [0.1510] G/ref_adv: [2.7995] G/ref_sty: [0.3954] G/ref_ds: [0.2954] G/ref_cyc: [0.1570] G/lambda_ds: [0.0505]
# Elapsed time [1 day, 12:04:32], Iteration [76520/100000], D/latent_real: [0.1525] D/latent_fake: [0.2379] D/latent_reg: [0.0840] D/ref_real: [0.1621] D/ref_fake: [0.0625] D/ref_reg: [0.0782] G/latent_adv: [3.1097] G/latent_sty: [0.1586] G/latent_ds: [0.0604] G/latent_cyc: [0.1449] G/ref_adv: [3.2319] G/ref_sty: [0.3735] G/ref_ds: [0.3016] G/ref_cyc: [0.1485] G/lambda_ds: [0.0505]
# Elapsed time [1 day, 12:05:24], Iteration [76540/100000], D/latent_real: [0.0707] D/latent_fake: [0.1997] D/latent_reg: [0.0659] D/ref_real: [0.1199] D/ref_fake: [0.1015] D/ref_reg: [0.0648] G/latent_adv: [3.0317] G/latent_sty: [0.1589] G/latent_ds: [0.0932] G/latent_cyc: [0.1482] G/ref_adv: [3.5550] G/ref_sty: [0.4324] G/ref_ds: [0.3515] G/ref_cyc: [0.1667] G/lambda_ds: [0.0505]
# Elapsed time [1 day, 12:06:15], Iteration [76560/100000], D/latent_real: [0.5237] D/latent_fake: [0.2541] D/latent_reg: [0.0927] D/ref_real: [0.1123] D/ref_fake: [0.1460] D/ref_reg: [0.0663] G/latent_adv: [1.9492] G/latent_sty: [0.1576] G/latent_ds: [0.1023] G/latent_cyc: [0.1583] G/ref_adv: [3.3991] G/ref_sty: [0.3419] G/ref_ds: [0.3280] G/ref_cyc: [0.1602] G/lambda_ds: [0.0504]
# Elapsed time [1 day, 12:07:07], Iteration [76580/100000], D/latent_real: [0.1126] D/latent_fake: [0.0695] D/latent_reg: [0.0770] D/ref_real: [0.0234] D/ref_fake: [0.1029] D/ref_reg: [0.0616] G/latent_adv: [3.5115] G/latent_sty: [0.1775] G/latent_ds: [0.1074] G/latent_cyc: [0.1735] G/ref_adv: [3.9514] G/ref_sty: [0.4105] G/ref_ds: [0.3725] G/ref_cyc: [0.1908] G/lambda_ds: [0.0504]
# Elapsed time [1 day, 12:07:59], Iteration [76600/100000], D/latent_real: [0.1695] D/latent_fake: [0.5373] D/latent_reg: [0.0835] D/ref_real: [0.1556] D/ref_fake: [0.0816] D/ref_reg: [0.0686] G/latent_adv: [2.7860] G/latent_sty: [0.1370] G/latent_ds: [0.0782] G/latent_cyc: [0.1635] G/ref_adv: [3.2577] G/ref_sty: [0.3468] G/ref_ds: [0.5082] G/ref_cyc: [0.1656] G/lambda_ds: [0.0504]
# ...
# Elapsed time [2 days, 4:37:12], Iteration [99200/100000], D/latent_real: [0.3334] D/latent_fake: [0.3898] D/latent_reg: [0.0730] D/ref_real: [0.3791] D/ref_fake: [0.1695] D/ref_reg: [0.0650] G/latent_adv: [2.8206] G/latent_sty: [0.1460] G/latent_ds: [0.1107] G/latent_cyc: [0.1477] G/ref_adv: [3.0025] G/ref_sty: [0.3991] G/ref_ds: [0.2803] G/ref_cyc: [0.1340] G/lambda_ds: [0.0278]
# Elapsed time [2 days, 4:38:04], Iteration [99220/100000], D/latent_real: [0.1319] D/latent_fake: [0.2213] D/latent_reg: [0.0523] D/ref_real: [0.1008] D/ref_fake: [0.0892] D/ref_reg: [0.0538] G/latent_adv: [2.9426] G/latent_sty: [0.1178] G/latent_ds: [0.0750] G/latent_cyc: [0.1373] G/ref_adv: [3.4211] G/ref_sty: [0.4383] G/ref_ds: [0.4074] G/ref_cyc: [0.1621] G/lambda_ds: [0.0278]
# Elapsed time [2 days, 4:38:56], Iteration [99240/100000], D/latent_real: [0.2266] D/latent_fake: [0.2435] D/latent_reg: [0.0840] D/ref_real: [0.2330] D/ref_fake: [0.3618] D/ref_reg: [0.0799] G/latent_adv: [2.7168] G/latent_sty: [0.1099] G/latent_ds: [0.0906] G/latent_cyc: [0.1716] G/ref_adv: [3.4353] G/ref_sty: [0.3010] G/ref_ds: [0.3551] G/ref_cyc: [0.1768] G/lambda_ds: [0.0278]
# Elapsed time [2 days, 4:39:48], Iteration [99260/100000], D/latent_real: [0.2833] D/latent_fake: [0.1567] D/latent_reg: [0.1014] D/ref_real: [0.0906] D/ref_fake: [0.0549] D/ref_reg: [0.0775] G/latent_adv: [3.1805] G/latent_sty: [0.1300] G/latent_ds: [0.1364] G/latent_cyc: [0.1313] G/ref_adv: [3.1963] G/ref_sty: [0.3611] G/ref_ds: [0.3198] G/ref_cyc: [0.1481] G/lambda_ds: [0.0277]
# Elapsed time [2 days, 4:40:40], Iteration [99280/100000], D/latent_real: [0.1355] D/latent_fake: [0.7623] D/latent_reg: [0.0961] D/ref_real: [0.8629] D/ref_fake: [0.0448] D/ref_reg: [0.0787] G/latent_adv: [2.6056] G/latent_sty: [0.1272] G/latent_ds: [0.0953] G/latent_cyc: [0.1294] G/ref_adv: [2.3022] G/ref_sty: [0.4500] G/ref_ds: [0.3695] G/ref_cyc: [0.1569] G/lambda_ds: [0.0277]
# Elapsed time [2 days, 4:41:32], Iteration [99300/100000], D/latent_real: [0.1362] D/latent_fake: [0.3394] D/latent_reg: [0.0894] D/ref_real: [0.4086] D/ref_fake: [0.0588] D/ref_reg: [0.0908] G/latent_adv: [2.2803] G/latent_sty: [0.1383] G/latent_ds: [0.0715] G/latent_cyc: [0.1629] G/ref_adv: [2.8035] G/ref_sty: [0.4374] G/ref_ds: [0.4053] G/ref_cyc: [0.1696] G/lambda_ds: [0.0277]
# Elapsed time [2 days, 4:42:24], Iteration [99320/100000], D/latent_real: [0.0931] D/latent_fake: [0.1870] D/latent_reg: [0.0702] D/ref_real: [0.1046] D/ref_fake: [0.0948] D/ref_reg: [0.0744] G/latent_adv: [3.6958] G/latent_sty: [0.1541] G/latent_ds: [0.0908] G/latent_cyc: [0.1710] G/ref_adv: [3.9803] G/ref_sty: [0.5377] G/ref_ds: [0.5021] G/ref_cyc: [0.1539] G/lambda_ds: [0.0277]
# Elapsed time [2 days, 4:43:15], Iteration [99340/100000], D/latent_real: [0.1653] D/latent_fake: [0.2818] D/latent_reg: [0.0863] D/ref_real: [0.0607] D/ref_fake: [0.1172] D/ref_reg: [0.0899] G/latent_adv: [3.1697] G/latent_sty: [0.1373] G/latent_ds: [0.0922] G/latent_cyc: [0.1236] G/ref_adv: [3.4358] G/ref_sty: [0.4084] G/ref_ds: [0.4645] G/ref_cyc: [0.1377] G/lambda_ds: [0.0277]
# Elapsed time [2 days, 4:44:07], Iteration [99360/100000], D/latent_real: [0.1314] D/latent_fake: [0.5618] D/latent_reg: [0.0801] D/ref_real: [0.6637] D/ref_fake: [0.1236] D/ref_reg: [0.0848] G/latent_adv: [2.0191] G/latent_sty: [0.1067] G/latent_ds: [0.0490] G/latent_cyc: [0.1257] G/ref_adv: [2.9691] G/ref_sty: [0.4620] G/ref_ds: [0.4221] G/ref_cyc: [0.1468] G/lambda_ds: [0.0276]
# Elapsed time [2 days, 4:44:59], Iteration [99380/100000], D/latent_real: [0.1216] D/latent_fake: [0.3450] D/latent_reg: [0.0846] D/ref_real: [0.3441] D/ref_fake: [0.0758] D/ref_reg: [0.0896] G/latent_adv: [2.1399] G/latent_sty: [0.1141] G/latent_ds: [0.0419] G/latent_cyc: [0.1336] G/ref_adv: [2.4088] G/ref_sty: [0.4092] G/ref_ds: [0.3192] G/ref_cyc: [0.1509] G/lambda_ds: [0.0276]
# Elapsed time [2 days, 4:45:51], Iteration [99400/100000], D/latent_real: [0.2917] D/latent_fake: [0.1763] D/latent_reg: [0.1034] D/ref_real: [0.0304] D/ref_fake: [0.1160] D/ref_reg: [0.0939] G/latent_adv: [3.5206] G/latent_sty: [0.1000] G/latent_ds: [0.0688] G/latent_cyc: [0.1423] G/ref_adv: [3.8675] G/ref_sty: [0.4127] G/ref_ds: [0.3712] G/ref_cyc: [0.1474] G/lambda_ds: [0.0276]
# Elapsed time [2 days, 4:46:43], Iteration [99420/100000], D/latent_real: [0.1943] D/latent_fake: [0.7002] D/latent_reg: [0.0921] D/ref_real: [0.8046] D/ref_fake: [0.0485] D/ref_reg: [0.0935] G/latent_adv: [1.1648] G/latent_sty: [0.1449] G/latent_ds: [0.0438] G/latent_cyc: [0.1445] G/ref_adv: [2.0877] G/ref_sty: [0.5449] G/ref_ds: [0.4675] G/ref_cyc: [0.1778] G/lambda_ds: [0.0276]
# Elapsed time [2 days, 4:47:35], Iteration [99440/100000], D/latent_real: [0.3722] D/latent_fake: [0.5254] D/latent_reg: [0.0887] D/ref_real: [0.7699] D/ref_fake: [0.1128] D/ref_reg: [0.0762] G/latent_adv: [1.6757] G/latent_sty: [0.1017] G/latent_ds: [0.0591] G/latent_cyc: [0.1520] G/ref_adv: [2.5143] G/ref_sty: [0.3986] G/ref_ds: [0.4114] G/ref_cyc: [0.1529] G/lambda_ds: [0.0276]
# Elapsed time [2 days, 4:48:27], Iteration [99460/100000], D/latent_real: [0.2081] D/latent_fake: [0.6857] D/latent_reg: [0.0677] D/ref_real: [0.5263] D/ref_fake: [0.0913] D/ref_reg: [0.0633] G/latent_adv: [2.0177] G/latent_sty: [0.1123] G/latent_ds: [0.0576] G/latent_cyc: [0.1483] G/ref_adv: [2.3431] G/ref_sty: [0.3870] G/ref_ds: [0.2251] G/ref_cyc: [0.1711] G/lambda_ds: [0.0275]
# Elapsed time [2 days, 4:49:19], Iteration [99480/100000], D/latent_real: [0.1419] D/latent_fake: [0.2492] D/latent_reg: [0.0691] D/ref_real: [0.1307] D/ref_fake: [0.0941] D/ref_reg: [0.0725] G/latent_adv: [2.6564] G/latent_sty: [0.1092] G/latent_ds: [0.1003] G/latent_cyc: [0.1630] G/ref_adv: [2.9342] G/ref_sty: [0.3872] G/ref_ds: [0.3167] G/ref_cyc: [0.1668] G/lambda_ds: [0.0275]
# Elapsed time [2 days, 4:50:11], Iteration [99500/100000], D/latent_real: [0.0842] D/latent_fake: [0.3733] D/latent_reg: [0.0706] D/ref_real: [0.2882] D/ref_fake: [0.1521] D/ref_reg: [0.0749] G/latent_adv: [2.6338] G/latent_sty: [0.1379] G/latent_ds: [0.0573] G/latent_cyc: [0.1577] G/ref_adv: [2.6208] G/ref_sty: [0.3745] G/ref_ds: [0.2911] G/ref_cyc: [0.1702] G/lambda_ds: [0.0275]
# Elapsed time [2 days, 4:51:03], Iteration [99520/100000], D/latent_real: [0.2029] D/latent_fake: [0.1496] D/latent_reg: [0.0559] D/ref_real: [0.0459] D/ref_fake: [0.0680] D/ref_reg: [0.0530] G/latent_adv: [2.7731] G/latent_sty: [0.1154] G/latent_ds: [0.0674] G/latent_cyc: [0.1500] G/ref_adv: [3.4480] G/ref_sty: [0.5213] G/ref_ds: [0.3195] G/ref_cyc: [0.1718] G/lambda_ds: [0.0275]
# Elapsed time [2 days, 4:51:54], Iteration [99540/100000], D/latent_real: [0.1302] D/latent_fake: [0.3826] D/latent_reg: [0.0667] D/ref_real: [0.3989] D/ref_fake: [0.0774] D/ref_reg: [0.0793] G/latent_adv: [1.8725] G/latent_sty: [0.1326] G/latent_ds: [0.0669] G/latent_cyc: [0.1650] G/ref_adv: [2.5597] G/ref_sty: [0.4995] G/ref_ds: [0.3167] G/ref_cyc: [0.1862] G/lambda_ds: [0.0275]
# Elapsed time [2 days, 4:52:46], Iteration [99560/100000], D/latent_real: [0.5899] D/latent_fake: [0.2397] D/latent_reg: [0.0731] D/ref_real: [0.0254] D/ref_fake: [0.2385] D/ref_reg: [0.0508] G/latent_adv: [3.0406] G/latent_sty: [0.1368] G/latent_ds: [0.0708] G/latent_cyc: [0.1644] G/ref_adv: [3.3364] G/ref_sty: [0.3678] G/ref_ds: [0.3373] G/ref_cyc: [0.1501] G/lambda_ds: [0.0274]
# Elapsed time [2 days, 4:53:38], Iteration [99580/100000], D/latent_real: [0.1150] D/latent_fake: [0.5531] D/latent_reg: [0.0887] D/ref_real: [0.7721] D/ref_fake: [0.0728] D/ref_reg: [0.0973] G/latent_adv: [1.8510] G/latent_sty: [0.1267] G/latent_ds: [0.0634] G/latent_cyc: [0.1404] G/ref_adv: [1.7966] G/ref_sty: [0.5082] G/ref_ds: [0.3205] G/ref_cyc: [0.1611] G/lambda_ds: [0.0274]
# Elapsed time [2 days, 4:54:30], Iteration [99600/100000], D/latent_real: [0.1831] D/latent_fake: [0.2084] D/latent_reg: [0.0727] D/ref_real: [0.0390] D/ref_fake: [0.0929] D/ref_reg: [0.0626] G/latent_adv: [3.5814] G/latent_sty: [0.1115] G/latent_ds: [0.0611] G/latent_cyc: [0.1429] G/ref_adv: [3.8785] G/ref_sty: [0.4307] G/ref_ds: [0.3778] G/ref_cyc: [0.1348] G/lambda_ds: [0.0274]
# Elapsed time [2 days, 4:55:22], Iteration [99620/100000], D/latent_real: [0.1573] D/latent_fake: [0.1864] D/latent_reg: [0.0641] D/ref_real: [0.0991] D/ref_fake: [0.1125] D/ref_reg: [0.0623] G/latent_adv: [2.7709] G/latent_sty: [0.1256] G/latent_ds: [0.0536] G/latent_cyc: [0.1359] G/ref_adv: [3.4373] G/ref_sty: [0.4249] G/ref_ds: [0.2678] G/ref_cyc: [0.1517] G/lambda_ds: [0.0274]
# Elapsed time [2 days, 4:56:14], Iteration [99640/100000], D/latent_real: [0.2516] D/latent_fake: [0.4440] D/latent_reg: [0.0898] D/ref_real: [0.4758] D/ref_fake: [0.1262] D/ref_reg: [0.1036] G/latent_adv: [1.6216] G/latent_sty: [0.1198] G/latent_ds: [0.0582] G/latent_cyc: [0.1262] G/ref_adv: [2.1441] G/ref_sty: [0.3734] G/ref_ds: [0.3769] G/ref_cyc: [0.1460] G/lambda_ds: [0.0274]
# Elapsed time [2 days, 4:57:06], Iteration [99660/100000], D/latent_real: [0.3103] D/latent_fake: [0.3585] D/latent_reg: [0.0662] D/ref_real: [0.3821] D/ref_fake: [0.0965] D/ref_reg: [0.0530] G/latent_adv: [2.1468] G/latent_sty: [0.1249] G/latent_ds: [0.0439] G/latent_cyc: [0.1238] G/ref_adv: [2.9960] G/ref_sty: [0.3497] G/ref_ds: [0.2987] G/ref_cyc: [0.1439] G/lambda_ds: [0.0273]
# Elapsed time [2 days, 4:57:58], Iteration [99680/100000], D/latent_real: [0.2445] D/latent_fake: [0.3494] D/latent_reg: [0.0785] D/ref_real: [0.3027] D/ref_fake: [0.0728] D/ref_reg: [0.0736] G/latent_adv: [2.2935] G/latent_sty: [0.1284] G/latent_ds: [0.0771] G/latent_cyc: [0.1650] G/ref_adv: [2.9167] G/ref_sty: [0.5146] G/ref_ds: [0.4071] G/ref_cyc: [0.1796] G/lambda_ds: [0.0273]
# Elapsed time [2 days, 4:58:50], Iteration [99700/100000], D/latent_real: [0.1041] D/latent_fake: [0.4334] D/latent_reg: [0.0727] D/ref_real: [0.3793] D/ref_fake: [0.0454] D/ref_reg: [0.0728] G/latent_adv: [2.3912] G/latent_sty: [0.1485] G/latent_ds: [0.0874] G/latent_cyc: [0.1955] G/ref_adv: [2.5492] G/ref_sty: [0.4273] G/ref_ds: [0.3504] G/ref_cyc: [0.1857] G/lambda_ds: [0.0273]
# Elapsed time [2 days, 4:59:42], Iteration [99720/100000], D/latent_real: [0.1948] D/latent_fake: [0.4664] D/latent_reg: [0.0643] D/ref_real: [0.3694] D/ref_fake: [0.1415] D/ref_reg: [0.0672] G/latent_adv: [2.4600] G/latent_sty: [0.1293] G/latent_ds: [0.0462] G/latent_cyc: [0.1259] G/ref_adv: [2.7911] G/ref_sty: [0.4300] G/ref_ds: [0.4118] G/ref_cyc: [0.1473] G/lambda_ds: [0.0273]
# Elapsed time [2 days, 5:00:34], Iteration [99740/100000], D/latent_real: [0.1464] D/latent_fake: [0.2454] D/latent_reg: [0.0926] D/ref_real: [0.1214] D/ref_fake: [0.0427] D/ref_reg: [0.0928] G/latent_adv: [3.2960] G/latent_sty: [0.1495] G/latent_ds: [0.0896] G/latent_cyc: [0.1775] G/ref_adv: [3.2113] G/ref_sty: [0.4673] G/ref_ds: [0.3974] G/ref_cyc: [0.1844] G/lambda_ds: [0.0273]
# Elapsed time [2 days, 5:01:25], Iteration [99760/100000], D/latent_real: [0.1520] D/latent_fake: [0.4817] D/latent_reg: [0.0744] D/ref_real: [0.4030] D/ref_fake: [0.0548] D/ref_reg: [0.0766] G/latent_adv: [2.2498] G/latent_sty: [0.1263] G/latent_ds: [0.1068] G/latent_cyc: [0.1422] G/ref_adv: [2.8407] G/ref_sty: [0.4968] G/ref_ds: [0.2876] G/ref_cyc: [0.1497] G/lambda_ds: [0.0272]
# Elapsed time [2 days, 5:02:17], Iteration [99780/100000], D/latent_real: [0.3831] D/latent_fake: [0.2079] D/latent_reg: [0.1107] D/ref_real: [0.2507] D/ref_fake: [0.0368] D/ref_reg: [0.1122] G/latent_adv: [2.8119] G/latent_sty: [0.1350] G/latent_ds: [0.0740] G/latent_cyc: [0.1232] G/ref_adv: [2.9020] G/ref_sty: [0.5049] G/ref_ds: [0.3984] G/ref_cyc: [0.1303] G/lambda_ds: [0.0272]
# Elapsed time [2 days, 5:03:09], Iteration [99800/100000], D/latent_real: [0.2416] D/latent_fake: [0.6078] D/latent_reg: [0.0855] D/ref_real: [0.4505] D/ref_fake: [0.0839] D/ref_reg: [0.0736] G/latent_adv: [2.4211] G/latent_sty: [0.1346] G/latent_ds: [0.0380] G/latent_cyc: [0.1158] G/ref_adv: [3.0609] G/ref_sty: [0.5242] G/ref_ds: [0.3195] G/ref_cyc: [0.1324] G/lambda_ds: [0.0272]
# Elapsed time [2 days, 5:04:01], Iteration [99820/100000], D/latent_real: [0.1563] D/latent_fake: [0.1793] D/latent_reg: [0.0725] D/ref_real: [0.0661] D/ref_fake: [0.0603] D/ref_reg: [0.0719] G/latent_adv: [2.9264] G/latent_sty: [0.1499] G/latent_ds: [0.0493] G/latent_cyc: [0.1440] G/ref_adv: [3.0292] G/ref_sty: [0.5015] G/ref_ds: [0.4712] G/ref_cyc: [0.1380] G/lambda_ds: [0.0272]
# Elapsed time [2 days, 5:04:53], Iteration [99840/100000], D/latent_real: [0.0972] D/latent_fake: [0.4550] D/latent_reg: [0.0728] D/ref_real: [0.6406] D/ref_fake: [0.0847] D/ref_reg: [0.0589] G/latent_adv: [2.5286] G/latent_sty: [0.0989] G/latent_ds: [0.0452] G/latent_cyc: [0.1561] G/ref_adv: [2.3087] G/ref_sty: [0.4454] G/ref_ds: [0.3847] G/ref_cyc: [0.1600] G/lambda_ds: [0.0272]
# Elapsed time [2 days, 5:05:45], Iteration [99860/100000], D/latent_real: [0.1177] D/latent_fake: [0.3170] D/latent_reg: [0.0739] D/ref_real: [0.5307] D/ref_fake: [0.0691] D/ref_reg: [0.0861] G/latent_adv: [1.9438] G/latent_sty: [0.1250] G/latent_ds: [0.0963] G/latent_cyc: [0.1452] G/ref_adv: [2.4090] G/ref_sty: [0.4120] G/ref_ds: [0.4246] G/ref_cyc: [0.1454] G/lambda_ds: [0.0271]
# Elapsed time [2 days, 5:06:37], Iteration [99880/100000], D/latent_real: [0.1876] D/latent_fake: [0.6251] D/latent_reg: [0.0810] D/ref_real: [0.7622] D/ref_fake: [0.0752] D/ref_reg: [0.0805] G/latent_adv: [2.0254] G/latent_sty: [0.1350] G/latent_ds: [0.0697] G/latent_cyc: [0.1555] G/ref_adv: [2.3071] G/ref_sty: [0.5285] G/ref_ds: [0.3248] G/ref_cyc: [0.1444] G/lambda_ds: [0.0271]
# Elapsed time [2 days, 5:07:28], Iteration [99900/100000], D/latent_real: [0.4993] D/latent_fake: [0.2441] D/latent_reg: [0.0815] D/ref_real: [0.0660] D/ref_fake: [0.2085] D/ref_reg: [0.0613] G/latent_adv: [2.1236] G/latent_sty: [0.1238] G/latent_ds: [0.0425] G/latent_cyc: [0.1084] G/ref_adv: [3.3351] G/ref_sty: [0.4453] G/ref_ds: [0.3547] G/ref_cyc: [0.1154] G/lambda_ds: [0.0271]
# Elapsed time [2 days, 5:08:20], Iteration [99920/100000], D/latent_real: [0.1435] D/latent_fake: [0.3593] D/latent_reg: [0.0741] D/ref_real: [0.2734] D/ref_fake: [0.1293] D/ref_reg: [0.0748] G/latent_adv: [2.8035] G/latent_sty: [0.1266] G/latent_ds: [0.0814] G/latent_cyc: [0.1711] G/ref_adv: [3.0732] G/ref_sty: [0.3971] G/ref_ds: [0.4085] G/ref_cyc: [0.1633] G/lambda_ds: [0.0271]
# Elapsed time [2 days, 5:09:12], Iteration [99940/100000], D/latent_real: [0.2029] D/latent_fake: [0.5583] D/latent_reg: [0.1079] D/ref_real: [0.4550] D/ref_fake: [0.0490] D/ref_reg: [0.0859] G/latent_adv: [2.3951] G/latent_sty: [0.1074] G/latent_ds: [0.0700] G/latent_cyc: [0.1204] G/ref_adv: [3.1487] G/ref_sty: [0.4686] G/ref_ds: [0.3139] G/ref_cyc: [0.1388] G/lambda_ds: [0.0271]
# Elapsed time [2 days, 5:10:04], Iteration [99960/100000], D/latent_real: [0.1289] D/latent_fake: [0.2696] D/latent_reg: [0.0856] D/ref_real: [0.1312] D/ref_fake: [0.1184] D/ref_reg: [0.0871] G/latent_adv: [2.9764] G/latent_sty: [0.1138] G/latent_ds: [0.0409] G/latent_cyc: [0.1338] G/ref_adv: [3.4361] G/ref_sty: [0.4673] G/ref_ds: [0.3877] G/ref_cyc: [0.1517] G/lambda_ds: [0.0270]
# Elapsed time [2 days, 5:10:56], Iteration [99980/100000], D/latent_real: [0.0636] D/latent_fake: [0.4364] D/latent_reg: [0.0780] D/ref_real: [0.8798] D/ref_fake: [0.0475] D/ref_reg: [0.0863] G/latent_adv: [1.7374] G/latent_sty: [0.1213] G/latent_ds: [0.0479] G/latent_cyc: [0.1486] G/ref_adv: [1.9449] G/ref_sty: [0.4412] G/ref_ds: [0.3878] G/ref_cyc: [0.1788] G/lambda_ds: [0.0270]
# Elapsed time [2 days, 5:11:48], Iteration [100000/100000], D/latent_real: [0.1961] D/latent_fake: [0.3920] D/latent_reg: [0.0717] D/ref_real: [0.3845] D/ref_fake: [0.1349] D/ref_reg: [0.0751] G/latent_adv: [2.4846] G/latent_sty: [0.1284] G/latent_ds: [0.0554] G/latent_cyc: [0.1184] G/ref_adv: [2.2821] G/ref_sty: [0.4287] G/ref_ds: [0.2119] G/ref_cyc: [0.1224] G/lambda_ds: [0.0270]
# Saving checkpoint into expr/checkpoints/nets.ckpt...
# Saving checkpoint into expr/checkpoints/nets_ema.ckpt...
# Saving checkpoint into expr/checkpoints/optims.ckpt...

# %%
#!g1.1:bash
cp expr/checkpoints/nets_ema.ckpt ./

# %%
#!g1.1
expr/checkpoints/nets_ema.ckpt
